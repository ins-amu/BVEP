# %% [markdown]
# # Implementing  BVEP brain network model in Stan

# %%
import os
import sys
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import re
import glob
from itertools import chain
from operator import itemgetter

import json
import pickle

import scikitplot as skplt
from sklearn.metrics import confusion_matrix

from scipy.optimize import fsolve
from scipy.optimize import root

# %%
import pystan

from parse_csv import parse_csv2
from read_csvs import read_samples

from report_nodetype import node_EzPzHz_idex
from report_metrics import LSE, Err, RMSE, LSE_obs, z_score, shrinkage
from report_nodetype import node_score_std_extrm, node_score_ezpz

# %%
import warnings
import yaml

warnings.filterwarnings('ignore')
warnings.simplefilter(action="ignore", category=FutureWarning)
yaml.warnings({'YAMLLoadWarning': False})

# %%
# %pylab inline
#%matplotlib inline

sns.set_style("white")
sns.set_context("talk")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def f_int(x):
    return np.int(x)

f_vector_int = np.vectorize(f_int)

# %%
numbers = re.compile(r'(\d+)')

def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %% [markdown]
# # Syntetic Data

# %%
data_dir = 'data_input_files'
results_dir = 'data_output_files'
os.makedirs(results_dir,exist_ok=True)
os.makedirs(f'{results_dir}/logs',exist_ok=True)
os.makedirs(f'{results_dir}/figures',exist_ok=True)

# %%
cwd = os.getcwd()
print("The results directory is:", cwd)
# Out:
# The results directory is: /data/BVEP_SEEG

# %%
Res_dir='data_output_files'

# %%
Mainpath =cwd+"/"

# %%
Reportmetrics_dir = os.path.join(cwd, Mainpath+"/data_output_files/figures/")

# %%
eta_true_inx, eta_true_mu, eta_true_sd = np.loadtxt(Mainpath+"ExperimentalData"+"/"+"eta_seeg_patient1"+".txt", delimiter=',', usecols=(0,1,2), skiprows=1, ).T

# %%
with open(Mainpath+"ExperimentalData"+"/"+"true_labels_nodes_patient1"+".txt", 'r') as filehandle:  
          true_labels_nodes = json.load(filehandle)

# %%
data_input = np.load(Mainpath+"data_input_files/"+"datainput_Seeg_84nodes_patient1.npz")
#data_input = np.load(f'{data_dir}/datainput_Seeg_84nodes_patient1.R.npz')

# %%
Obs_seeg = data_input['Obs_seeg']
x_source=data_input['x_source']
z_source=data_input['z_source']

SC = data_input['SC']
Gr = data_input['Gr']
ts = data_input['ts']
tau0 = data_input['tau0']
Ks = data_input['Ks']

ez_idx=data_input['ez_idx']
pz_idx=data_input['pz_idx']

ez_val=data_input['ez_val']
pz_val=data_input['pz_val']
hz_val=data_input['hz_val']

nn=data_input['nn']
ns=data_input['ns']
nt=data_input['nt']

# %%
nodes=np.r_[0:nn]

# %%
Obs_seeg.shape, x_source.shape
# Out:
# ((130, 162), (130, 84))

# %%
I1=3.1
eta_c=-2.05        
delta_eta=1.0                  
prior_std =1.0
sd_thr=0.8

# %%
eta_ez= float(ez_val)
eta_pz= float(pz_val)
eta_hz= float(hz_val)

# %%
eta_ez, eta_pz, eta_hz
# Out:
# (-1.6, -2.4, -3.5)

# %%
ez_idx, pz_idx
# Out:
# (array([ 6, 34], dtype=int32), array([27,  5, 11], dtype=int32))

# %%
Ez_indices, Pz_indices, Hz_indices, Ez_arr, Pz_arr, Hz_arr= node_EzPzHz_idex(true_labels_nodes)

# %%
print("Ez_indices:", Ez_indices)
print("Pz_indices:", Pz_indices)
# Out:
# Ez_indices: [6, 34]
# Pz_indices: [5, 11, 27]

# %% [markdown]
# # Provisioning BVEP

# %% [markdown]
# ## Observation

# %%
Obs_seeg.shape
# Out:
# (130, 162)

# %%
Seeg= Obs_seeg.T
Seeg.shape
# Out:
# (162, 130)

# %%
Seeg_area = np.trapz(Seeg, dx=0.0001)

# %%
plt.figure(figsize=(18, 4))
plt.bar(np.arange(1,Seeg_area.shape[0]+1), -Seeg_area, color='black', alpha=0.3);
plt.xlabel('Brain regions', fontsize=22)
plt.ylabel('SEEG env power', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Obs_SEEG_envelop_power.png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Obs_SEEG_envelop_power.eps"), doi=800)
plt.show()

# %%
Seeg_pwr = np.sum((Seeg*Seeg), axis=1)
Seeg_pwr_n = (Seeg_pwr/ Seeg_pwr.max())

# %%
plt.figure(figsize=(18, 4))
plt.bar(np.arange(1, Seeg_pwr_n.shape[0]+1), Seeg_pwr_n, color='black', alpha=0.3);
plt.xlabel('Brain regions', fontsize=24)
plt.ylabel('SEEG norm power', fontsize=24)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Obs_SEEG_envelop_power_normalize.png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Obs_SEEG_envelop_power_normalize.eps"), doi=800)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.subplot(211)
plt.plot(Seeg.T, linewidth=4, alpha=0.2);
plt.title('Simulated seizure envelop at sensor level measurement')
plt.xlabel('Time', fontsize=22)
plt.ylabel('SEEG envelope', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)

plt.subplot(212)
plt.bar(np.arange(1,Seeg_pwr_n.shape[0]+1), Seeg_pwr_n, color='r', alpha=0.2)
plt.title('Normalized power of simulated seizure envelop sensor level measurement')
plt.xlabel('Brain regions', fontsize=22)
plt.ylabel('SEEG norm power', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Observed_SEEGdata.png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Observed_SEEGdata.eps"), doi=800)
plt.show()

# %%
xs=x_source
zs=z_source

xs.shape, zs.shape
# Out:
# ((130, 84), (130, 84))

# %%
xs_pwr = (xs*xs).sum (axis=0)
xs_pwr_n = (xs_pwr/ xs_pwr.max())

# %%
eni_idx=np.argsort(xs_pwr)
eni_idx
# Out:
# array([ 6, 34, 27, 11,  5, 83,  9, 29,  7, 23, 60, 14, 13, 20,  3, 28, 54,
#        22, 39, 35,  8, 19,  4, 26,  0,  2, 58, 72, 76, 37, 33, 52, 63, 10,
#        57, 36, 25, 68, 56, 15, 42, 38, 31, 12, 53, 40, 69, 32, 46, 75, 64,
#        77, 21, 71, 43, 59, 44, 78, 16, 82, 62, 45, 61, 70, 18, 17, 41,  1,
#        24, 55, 47, 74, 48, 80, 51, 30, 81, 66, 73, 79, 67, 50, 65, 49])

# %%
plt.figure(figsize=(12,8))
plt.subplot(211)
plt.plot(xs, linewidth=4, alpha=0.2);
for i in range(xs.shape[1]):
    if i in Ez_indices:
        plot(xs[:,i], linestyle='-', marker='.', linewidth=4, color='r', alpha=2./i)
    elif i in Pz_indices:
        plot(xs[:,i], linestyle='--', marker='.',linewidth=2, color='y', alpha=4./i)
    else: 
        plot(xs[:,i], linestyle='-', linewidth=2, color='g', alpha=0.5)
plt.title('Simulated source level activity  (hidden-states)')
plt.xlabel('time', fontsize=15)
plt.ylabel('Epileptor fast activity (xs)', fontsize=15)
plt.subplot(212)
plt.bar(np.arange(1,xs_pwr_n.shape[0]+1), 1.-xs_pwr_n, color='black', alpha=0.3)
plt.title('Normalized power of simulated source level activity  (hidden-states')
plt.xlabel('brain regions', fontsize=15)
plt.ylabel('envelope power', fontsize=15)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"UnobserveSourceActivity.png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"UnobserveSourceActivity.eps"), doi=800)
plt.show()

# %%
Seeg.shape, xs.shape
# Out:
# ((162, 130), (130, 84))

# %% [markdown]
# ## NonCenterized form of parameterization

# %%
! cat BVEP_seeg_noncentered_reparam.stan
# Out:
# data {
#   int nn;  //number of brain regions
#   int nt;  //number of data points per sensor
#   int ns;  //number of sensors
#
#   real dt;    //time step in Euler integration
#   real tau0;  //time scale in Eipleptor model
#   real I1;    //input current in in Eipleptor model
#   real Ks;    //global connectivity parameter
#
#   matrix[nt, ns] Obs_seeg;      // observation at sensor-level
#   matrix[nn, nn] SC;           // brain structural connectivity
#   matrix[ns, nn] Gr;           // gain (projection matrix)
#   matrix[nn, nn] eigen_vec;   // eigen vectors of dot(Gr.T, Gr)
#
#   real zlim[2];
#   real xlim[2];
#
# }
#
# transformed data {
#   vector[nt*ns] Obs_seeg_vect;
#   Obs_seeg_vect=to_vector(Obs_seeg);
# }
#
# parameters {
#   vector[nn] x_init_star;
#   vector[nn] z_init_star;
#   vector[nn] eta_star;
#   real <lower=-1.0> K_star;
#   real <lower=-1.0> amplitude_star;
#   vector [ns] offset_star;
#   real eps_star;
# }
#
# transformed parameters {
#   vector[nn] eta;
#   vector[nn] x_init;
#   vector[nn] z_init;
#   real K;
#   real amplitude;
#   vector[ns] offset;
#   real eps;
#
#   eta =  -3.5+0.1*eigen_vec*eta_star;
#   x_init= -2.0 +0.1*eigen_vec*x_init_star;
#   z_init= 5.0+0.1*eigen_vec*z_init_star;
#   K =  Ks + 0.1*K_star;
#   amplitude = 1.0 + amplitude_star;
#   offset=offset_star+10.0;
#   eps=exp(0.33*eps_star);
# }
#
# model {
#   matrix[nn, nt] x;
#   matrix[nn, nt] z;
#   matrix[nt, ns] Seeg;
#   vector[nt*ns] Seeg_vect;
#
#   real dx;
#   real dz;
#   real gx;
#
#   /* priors*/
#
#   eta_star ~ normal(0.,1.0);
#   x_init_star ~ normal(0.,1.0);
#   z_init_star ~ normal(0, 1.0);
#   K_star ~ normal(0., 1.);
#   amplitude_star ~ normal(0. ,1.);
#   offset_star ~ normal(0.,1.);
#   eps_star ~ normal(0.,1.);
#
#
#   /* integrate & predict */
#
#     for (i in 1:nn) {
#       x[i, 1] =  x_init[i];
#       z[i, 1] =  z_init[i];
#     }
#
#   for (t in 1:(nt-1)) {
#     for (i in 1:nn) {
#       gx = 0;
#       for (j in 1:nn)
#         gx = gx + SC[i, j]*(x[j, t] - x[i, t]);
#       dx = 1.0 - x[i, t]*x[i, t]*x[i, t] - 2.0*x[i, t]*x[i, t] - z[i, t] + I1;
#       dz = (1/tau0)*(4*(x[i, t] - eta[i]) - z[i, t] - K*gx);
#       x[i, t+1] = x[i, t] + dt*dx ;
#       z[i, t+1] = z[i, t] + dt*dz ;
#     }
#   }
#
#   for(i in 1:nt){
#     Seeg[i,]=to_row_vector(amplitude*(Gr*x[,i])+offset);
#   }
#
#   Seeg_vect=to_vector(Seeg);
#
#   for(i in (10*ns+1):(nt*ns)){
#     target+=  normal_lpdf(Obs_seeg_vect[i]| Seeg_vect[i], eps);
#   }
# }
#
# generated quantities {
#
#   matrix[nn, nt] x;
#   matrix[nn, nt] z;
#
#   matrix[nt,ns] Seeg_qqc;
#   vector[nt*ns] Seeg_qqc_vect;
#   vector[nt*ns] Seeg_ppc;
#   vector[nt*ns] log_lik;
#   vector[nt] log_lik_sum = rep_vector(0,nt);
#
#   real gx;
#   real dx;
#   real dz;
#
#
#   for (i in 1:nn) {
#     x[i, 1] = x_init[i];
#     z[i, 1] = z_init[i];
#   }
#
#   for (t in 1:(nt-1)) {
#     for (i in 1:nn) {
#       gx = 0;
#       for (j in 1:nn)
#         gx = gx + SC[i, j]*(x[j, t] - x[i, t]);
#       dx = 1.0 - x[i, t]*x[i, t]*x[i, t] - 2.0*x[i, t]*x[i, t] - z[i, t] + I1;
#       dz = (1/tau0)*(4*(x[i, t] - eta[i]) - z[i, t] - K*gx);
#       x[i, t+1] = x[i, t] + dt*dx ;
#       z[i, t+1] = z[i, t] + dt*dz ;
#     }
#   }
#
#
#
#   for(i in 1:nt){
#     Seeg_qqc[i,]=to_row_vector(amplitude*(Gr*x[,i])+offset);
#   }
#
#
#   Seeg_qqc_vect=to_vector(Seeg_qqc);
#
#   for (i in 1:(nt*ns)){
#         Seeg_ppc[i] = normal_rng(Seeg_qqc_vect[i], eps);
#       }
#
#
#   for (i in 1:(nt*ns)){
#         log_lik[i] = normal_lpdf(Obs_seeg_vect[i]| Seeg_qqc_vect[i], eps);
#       }
#
#
#   for (i in 1:nt){
#         for (j in 1:ns)
#             log_lik_sum[i] += normal_lpdf(Obs_seeg[i,j]| Seeg_qqc[i,j], eps);
#       }
#
# }

# %%
model=str('BVEP_seeg_noncentered_reparam')

# %%
curr_dir=cwd

# %%
! cd /home/meysam/cmdstan && make $curr_dir/$model && cd $curr_dir
# Out:
# --- Translating Stan model to C++ code ---
# bin/stanc  /data/BVEP_SEEG/BVEP_seeg_noncentered_reparam.stan --o=/data/BVEP_SEEG/BVEP_seeg_noncentered_reparam.hpp
# Model name=BVEP_seeg_noncentered_reparam_model
# Input file=/data/BVEP_SEEG/BVEP_seeg_noncentered_reparam.stan
# Output file=/data/BVEP_SEEG/BVEP_seeg_noncentered_reparam.hpp
#
# --- Linking C++ model ---
# g++ -Wall -I . -isystem stan/lib/stan_math/lib/eigen_3.3.3 -isystem stan/lib/stan_math/lib/boost_1.64.0 -isystem stan/lib/stan_math/lib/cvodes_2.9.0/include -std=c++1y -DBOOST_RESULT_OF_USE_TR1 -DBOOST_NO_DECLTYPE -DBOOST_DISABLE_ASSERTS -DBOOST_PHOENIX_NO_VARIADIC_EXPRESSION -Wno-unused-function -Wno-uninitialized -I src -isystem stan/src -isystem stan/lib/stan_math/ -DFUSION_MAX_VECTOR_SIZE=12 -Wno-unused-local-typedefs -DEIGEN_NO_DEBUG -O3 -march=native -mtune=native -DNO_FPRINTF_OUTPUT -pipe    -O3 -o /data/BVEP_SEEG/BVEP_seeg_noncentered_reparam src/cmdstan/main.cpp -include /data/BVEP_SEEG/BVEP_seeg_noncentered_reparam.hpp stan/lib/stan_math/lib/cvodes_2.9.0/lib/libsundials_nvecserial.a stan/lib/stan_math/lib/cvodes_2.9.0/lib/libsundials_cvodes.a

# %%
# %%bash
#
# alg=hmc
# adap_delta=0.99
# max_depth=10
# num_iter=500
# warm_iter=2000
#
# model=BVEP_seeg_noncentered_reparam
# data_input=datainput_Seeg_84nodes_patient1.R
# data_output=data_output_${alg}_${model}
#
# mkdir -p ${data_output}
#
#
# for i in `seq 4`
# do
#     ./$model id=$i\
#         sample save_warmup=0 num_warmup=${warm_iter} num_samples=${num_iter} \
#         adapt \
#         delta=${adap_delta} \
#         algorithm=${alg} \
#         engine=nuts \
#         max_depth=${max_depth}  \
#         data file=data_input_files/${data_input}\
#         output file=${data_output}/output_${alg}_${model}_$i.csv refresh=1 \
#         &> ${data_output}/output_${alg}_${model}_$i.out &
# done
# #wait

# %%
fit_foldername="data_output_hmc_"+model
fit_filename="output_hmc_"+model

# %%
dir_data_output=cwd+"/"+fit_foldername
dir_data_output
# Out:
# '/data/BVEP_SEEG/data_output_hmc_BVEP_seeg_noncentered_reparam'

# %%
! ls $dir_data_output
# Out:
# output_hmc_BVEP_seeg_noncentered_reparam_1.csv
# output_hmc_BVEP_seeg_noncentered_reparam_1.out
# output_hmc_BVEP_seeg_noncentered_reparam_2.csv
# output_hmc_BVEP_seeg_noncentered_reparam_2.out
# output_hmc_BVEP_seeg_noncentered_reparam_3.csv
# output_hmc_BVEP_seeg_noncentered_reparam_3.out
# output_hmc_BVEP_seeg_noncentered_reparam_4.csv
# output_hmc_BVEP_seeg_noncentered_reparam_4.out
# summary_output_hmc_BVEP_seeg_noncentered_reparam_1.csv

# %%
# !tail -n2 $dir_data_output/*$model*out
# Out:
# ==> /data/BVEP_SEEG/data_output_hmc_BVEP_seeg_noncentered_reparam/output_hmc_BVEP_seeg_noncentered_reparam_1.out <==
#                186894 seconds (Total)
#
#
# ==> /data/BVEP_SEEG/data_output_hmc_BVEP_seeg_noncentered_reparam/output_hmc_BVEP_seeg_noncentered_reparam_2.out <==
#                188949 seconds (Total)
#
#
# ==> /data/BVEP_SEEG/data_output_hmc_BVEP_seeg_noncentered_reparam/output_hmc_BVEP_seeg_noncentered_reparam_3.out <==
#                186753 seconds (Total)
#
#
# ==> /data/BVEP_SEEG/data_output_hmc_BVEP_seeg_noncentered_reparam/output_hmc_BVEP_seeg_noncentered_reparam_4.out <==
#                189125 seconds (Total)

# %% [markdown]
# ## check the convergence

# %%
chain=1

# %%
cvsfinemane='output_hmc_'+str(model)+'_'+str(chain)+'.csv'
cvsfinemane
# Out:
# 'output_hmc_BVEP_seeg_noncentered_reparam_1.csv'

# %%
fit_filename_csv= fit_filename +'_'+ str(chain)+'.csv'
fit_filename_out= fit_filename +'_'+ str(chain)+'.out'

# %%
with open(dir_data_output+"/"+fit_filename_out, 'r') as f:
    lines = f.readlines()
    last_lines = lines[-7:]
    print (last_lines[1], last_lines[3], last_lines[4], last_lines[5]  )
# Out:
# Iteration: 2500 / 2500 [100%]  (Sampling)
#   Elapsed Time: 147869 seconds (Warm-up)
#                 39024.8 seconds (Sampling)
#                 186894 seconds (Total)

# %%
from report_algconfigs import hmc_config
num_samples, num_warmup, save_warmup,  adapt_delta, max_depth, total_time=hmc_config(dir_data_output+"/"+fit_filename_out)

# %%
num_samples=int(num_samples)

# %%
if int(save_warmup)==0:
    Burnin=0
nSample=num_samples-Burnin

# %% [markdown]
# ## posterior predictive density

# %%
fit= parse_csv2(dir_data_output+"/", fit_filename_csv)

# %%
for key, val in fit.items():
    print(key, val.shape)
# Out:
# lp__ (500,)
# accept_stat__ (500,)
# stepsize__ (500,)
# treedepth__ (500,)
# n_leapfrog__ (500,)
# divergent__ (500,)
# energy__ (500,)
# x_init_star (500, 84)
# z_init_star (500, 84)
# eta_star (500, 84)
# K_star (500,)
# amplitude_star (500,)
# offset_star (500, 162)
# eps_star (500,)
# eta (500, 84)
# x_init (500, 84)
# z_init (500, 84)
# K (500,)
# amplitude (500,)
# offset (500, 162)
# eps (500,)
# x (500, 130, 84)
# z (500, 130, 84)
# Seeg_qqc (500, 162, 130)
# Seeg_qqc_vect (500, 21060)
# Seeg_ppc (500, 21060)
# log_lik (500, 21060)
# log_lik_sum (500, 130)
# gx (500,)
# dx (500,)
# dz (500,)

# %%
Seeg_est=fit['Seeg_qqc'][-nSample:]
x_est=fit['x'][-nSample:]
z_est=fit['z'][-nSample:]

# %%
Seeg_est.shape, x_est.shape
# Out:
# ((500, 162, 130), (500, 130, 84))

# %%
Seeg.shape, xs.shape
# Out:
# ((162, 130), (130, 84))

# %%
eta_est=fit['eta'][-nSample:]
K_est=fit['K'][-nSample:]
amplitude_est=fit['amplitude'][-nSample:]
offset_est=fit['offset'][-nSample:]
eps_est=fit['eps'][-nSample:]

# %%
eta_est.shape, K_est.shape, amplitude_est.shape, offset_est.shape, eps_est.shape
# Out:
# ((500, 84), (500,), (500,), (500, 162), (500,))

# %%
eta_est_mean=np.mean(eta_est, axis=0)
eta_est_std=np.std(eta_est, axis=0)

# %%
Seeg_est_low, Seeg_est_hi = percentile(Seeg_est, [5, 95], axis=0)
LSE_val_fit=LSE_obs(Seeg, Seeg_est_low, Seeg_est_hi)
print('LSE_val_fit=', LSE_val_fit)
# Out:
# LSE_val_fit= 202454.16103766375

# %%
x_est_low, x_est_hi = percentile(x_est, [5, 95], axis=0)
LSE_val_fit_x=LSE_obs(xs, x_est_low, x_est_hi)
print('LSE_val_nuts=', LSE_val_fit_x)
# Out:
# LSE_val_nuts= 23.42093807757723

# %%
err_eta_est=Err(eta_true_mu, eta_est_mean)
z_score_eta_est=np.sum(z_score(eta_true_mu, eta_est_mean, eta_est_std))
shrinkage_eta_est=np.mean(shrinkage([prior_std]*nodes.shape[0], eta_est_std))

# %%
score_std_est, score_extrm_est= node_score_std_extrm(nodes, eta_est, eta_true_mu, sd_thr)
score_ez_est, score_pz_est, ce_est, cp_est, nodes_est_est, est_labels_nodes= node_score_ezpz(nodes, eta_est, true_labels_nodes, eta_c, delta_eta, 1.)
print ('Prediction about Ez and Pz nodes is=', int(score_ez_est+score_pz_est),' out of', len(Ez_indices)+len(Pz_indices), ' EzPznodes')
# Out:
# Prediction about Ez and Pz nodes is= 5  out of 5  EzPznodes

# %%
y_true=true_labels_nodes
y_pred=est_labels_nodes                                           
confusion_matrix_values= confusion_matrix(y_true, y_pred, labels=["EZ", "PZ", "HZ"])
accuracy_nuts=100*np.trace(confusion_matrix_values)/np.sum(confusion_matrix_values)
print ('Prediction about all the node types is=', int(np.trace(confusion_matrix_values)),' out of', len(nodes), ' nodes')
# Out:
# Prediction about all the node types is= 84  out of 84  nodes

# %%
showpicks = f_vector_int(np.r_[int(Hz_indices[0]), int(Pz_indices[0]), int(Ez_indices[0])])
showpicks=showpicks.tolist()
print("Shown nodes are:", [(x+1) for x in showpicks])
# Out:
# Shown nodes are: [1, 6, 7]

# %%
Seeg.shape, Seeg_est.shape, Seeg_est_low.shape
# Out:
# ((162, 130), (500, 162, 130), (162, 130))

# %%
xs.shape, x_est.shape, x_est_low.shape
# Out:
# ((130, 84), (500, 130, 84), (130, 84))

# %%
from report_plots import plot_features, plot_zscore_shrinkage,  plot_posterior, ppplot, plot_obs_x, plot_obs_z, plot_hiddenstates_x, plot_hiddenstates_z, plot_confusion_matrix

# %%
plt.figure(figsize=(18, 6)) 
subplot(121)
plt.plot(ts, Seeg.T, alpha=0.5, marker= '.' , markersize=4)
plt.ylabel(' Observed SEEG', fontsize=20);  
plt.xlabel('Time (s)', fontsize=20);
subplot(122)
plt.plot(ts, np.mean(Seeg_est, axis=0).T,  '--' , markersize=2)
plt.ylabel(' Fitted SEEG', fontsize=20);  
plt.xlabel('Time (s)', fontsize=20);
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"FittedSEEG"+str(model)+"_chain_"+str(chain)+".png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"FittedSEEG"+str(model)+"_chain_"+str(chain)+".eps"), doi=800)
plt.show()

# %%
plt.figure(figsize=(18, 6)) 
subplot(121)
plt.plot(ts, xs, alpha=0.5, marker= '.' , markersize=8, lw=4)
plt.ylabel(' Unobserved source activity', fontsize=20);  
plt.xlabel('Time (s)', fontsize=20);
subplot(122)
plt.plot(ts, np.mean(x_est, axis=0),  '--' , markersize=8, lw=4)
plt.ylabel(' Estimated source activity', fontsize=20);  
plt.xlabel('Time (s)', fontsize=20);
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"FittedSourceActivity"+str(model)+"_chain_"+str(chain)+".png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"FittedSourceActivity"+str(model)+"_chain_"+str(chain)+".eps"), doi=800)
plt.show()

# %%
plt.figure(figsize=(14, 4)) 
plot_posterior(nodes, eta_c, delta_eta, eta_hz, eta_ez, eta_pz, np.asarray(Hz_indices), np.asarray(Ez_indices), np.asarray(Pz_indices), eta_est)
plt.xticks(np.arange(1,len(nodes)+2, step=2),np.arange(1, len(nodes)+1, step=2), fontsize=10, rotation=0)
plt.ylabel(' Posterior ' +r'${(\eta_i)}$', fontsize=20);  
plt.xlabel('Brain nodes', fontsize=20); 
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"PosteriorExcitability"+str(model)+"_chain_"+str(chain)+".png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"PosteriorExcitability"+str(model)+"_chain_"+str(chain)+".eps"), doi=800)
plt.show()

# %%
plt.figure(figsize=(14, 6))  
grid = plt.GridSpec(2, 4)  
plt.subplot(grid[0, :2]) 
plot_features(ts, xs, x_est, showpicks)
plt.subplot(grid[0, 2]) 
plot_zscore_shrinkage(nodes, eta_true_mu, eta_est_mean, eta_est_std, prior_std)
plt.subplot(grid[0, 3]) 
plot_confusion_matrix(confusion_matrix_values, ["EZ", "PZ", "HZ"])
plt.subplot(grid[1, 0:])            
plot_posterior(nodes, eta_c, delta_eta, eta_hz, eta_ez, eta_pz, np.asarray(Hz_indices), np.asarray(Ez_indices), np.asarray(Pz_indices), eta_est)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"FitSource"+str(model)+"_chain_"+str(chain)+".png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"FitSource"+str(model)+"_chain_"+str(chain)+".eps"), doi=800)
plt.show()

# %%
from report_plots import pair_plots_params
extras = ' amplitude K eps'.split()              
plt.figure(figsize=(12, 8)) 
pair_plots_params(fit, extras)  
plt.tight_layout()
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Pairplot"+str(model)+"_chain_"+str(chain)+".png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Pairplot"+str(model)+"_chain_"+str(chain)+".eps"), doi=800)
plt.show()

# %%
from report_plots import func_2DepileptorEqs,  plot_phasespace

I=I1+1;
InitialGuess=np.array([[-1.0, 3.0]])
rGuess = np.repeat(InitialGuess, int(nn), axis=0)

true_roots_K0 = fsolve(func_2DepileptorEqs,rGuess, args=(eta_true_mu, 0.0, I, SC))
true_roots = fsolve(func_2DepileptorEqs,rGuess, args=(eta_true_mu, Ks, I, SC))

estimated_roots_K0 = fsolve(func_2DepileptorEqs,rGuess, args=(eta_est_mean, 0.0, I, SC))
estimated_roots = fsolve(func_2DepileptorEqs,rGuess, args=(eta_est_mean, K_est.mean(), I, SC))

# %%
plt.figure(figsize=(14, 6)) 
plot_phasespace(fit, data_input, nodes, showpicks, SC,  eta_true_mu, Ks,  true_roots, true_roots_K0, estimated_roots, estimated_roots_K0);
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Phaseplane"+str(model)+"_chain_"+str(chain)+".png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Phaseplane"+str(model)+"_chain_"+str(chain)+".eps"), doi=800)
plt.show();

# %% [markdown]
# ## Posterior convergence and diagnostics

# %%
divergent__=fit['divergent__'][-nSample:][:,newaxis]
stepsize__=fit['stepsize__'][-nSample:][:,newaxis]

lp__=fit['lp__'][-nSample:][:,newaxis]
accept_stat__=fit['accept_stat__'][-nSample:][:,newaxis]
energy__=fit['energy__'][-nSample:][:,newaxis]

treedepth__=fit['treedepth__'][-nSample:][:,newaxis]
n_leapfrog__=fit['n_leapfrog__'][-nSample:][:,newaxis]

# %%
figure(figsize=(10, 6))

plt.subplot(321)
plt.plot(lp__, 'b')
plt.ylabel("$lp$")
plt.subplot(322)
plt.plot(accept_stat__, 'b')
plt.ylabel("$accept_stat$")

plt.subplot(323)
plt.plot(stepsize__, 'b')
plt.ylabel("$stepsize$")
plt.subplot(324)
plt.plot(divergent__, 'b')
plt.ylabel("$divergent$")

plt.subplot(325)
plt.plot(n_leapfrog__, 'b')
plt.ylabel("$n_leapfrog$")
plt.subplot(326)
plt.plot(treedepth__, 'b')
plt.ylabel("$treedepth$")

tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Nuts_diagnostics_"+str(model)+"_chain_"+str(chain)+".png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Nuts_diagnostics_"+str(model)+"_chain_"+str(chain)+".eps"), doi=800)
plt.show()

# %%
from  report_diagnostics_stan import  run_summary, Nuts_plot, check_rhat, check_div, check_treedepth, check_energy, check_n_eff

# %%
dict_samples_diagnostics=read_samples(dir_data_output+"/"+str(fit_filename_csv), nwarmup=0, nsampling=num_samples,  variables_of_interest=['lp__', 'energy__', 'accept_stat__', 'divergent__', 'treedepth__', 'n_leapfrog__'  ])

# %%
lp__, accept_stat__, treedepth__, divergent__, energy__,  = dict_samples_diagnostics['lp__'], dict_samples_diagnostics['accept_stat__'],  dict_samples_diagnostics['treedepth__'], dict_samples_diagnostics['divergent__'], dict_samples_diagnostics['energy__']

# %%
check_divergence__=check_div(divergent__)
check_treedepth__=check_treedepth(treedepth__, int(max_depth))
check_energy__=check_energy(energy__)

# %%
check_divergence__, check_treedepth__, check_energy__
# Out:
# (0.0, 100.0, 1.044944210542196)

# %%
fit_summary=run_summary(cwd+"/", dir_data_output+"/"+str(fit_filename_csv))
# Out:
# fit_filefoder: data_output_hmc_BVEP_seeg_noncentered_reparam
# fit_filename: output_hmc_BVEP_seeg_noncentered_reparam_1.csv
# mycsvfile: /data/BVEP_SEEG/data_output_hmc_BVEP_seeg_noncentered_reparam/output_hmc_BVEP_seeg_noncentered_reparam_1.csv
# running stan summary!
# finished stan summary!

# %%
cd ..
# Out:
# /data/BVEP_SEEG

# %%
fit_summary
# Out:
#                     name          Mean          MCSE        StdDev  \
# 0                   lp__ -50297.800000  9.647780e-01  1.386460e+01
# 1          accept_stat__      0.991247  5.697420e-04  1.273980e-02
# 2             stepsize__      0.003828  7.969130e-18  5.643500e-18
# 3            treedepth__     10.000000  3.180830e-16  7.112540e-15
# 4           n_leapfrog__   1023.000000  5.089320e-14  1.138010e-12
# ...                  ...           ...           ...           ...
# 107049  log_lik_sum[129]   -419.063000  8.427680e-02  1.884490e+00
# 107050  log_lik_sum[130]   -409.930000  6.097070e-02  1.363350e+00
# 107051                gx      0.240949  1.275550e-03  2.852220e-02
# 107052                dx     -0.004764  1.806570e-05  4.039610e-04
# 107053                dz      0.023787  1.439830e-04  3.219560e-03
#
#                   5%           50%           95%       N_Eff   N_Eff/s  \
# 0      -50321.400000 -50297.700000 -50274.900000  206.520000  0.005292
# 1           0.966112      0.995887      0.999924  500.000000  0.012812
# 2           0.003828      0.003828      0.003828    0.501505  0.000013
# 3          10.000000     10.000000     10.000000  500.000000  0.012812
# 4        1023.000000   1023.000000   1023.000000  500.000000  0.012812
# ...              ...           ...           ...         ...       ...
# 107049   -422.306000   -418.998000   -416.009000  500.000000  0.012812
# 107050   -412.099000   -409.944000   -407.718000  500.000000  0.012812
# 107051      0.194087      0.242521      0.285438  500.000000  0.012812
# 107052     -0.005451     -0.004757     -0.004130  500.000000  0.012812
# 107053      0.018766      0.023664      0.029097  500.000000  0.012812
#
#            R_hat
# 0       1.011830
# 1       0.999870
# 2       0.997998
# 3       0.997998
# 4       0.997998
# ...          ...
# 107049  0.999185
# 107050  0.999465
# 107051  0.998724
# 107052  0.998004
# 107053  0.998417
#
# [107054 rows x 10 columns]

# %%
plt.figure(figsize=(10,8))
Nuts_plot(dict_samples_diagnostics, fit_summary)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Nuts_convergence_"+str(model)+"_chain_"+str(chain)+".png"), doi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir)+'/figures',"Nuts_convergence_"+str(model)+"_chain_"+str(chain)+".eps"), doi=800)
plt.show()
