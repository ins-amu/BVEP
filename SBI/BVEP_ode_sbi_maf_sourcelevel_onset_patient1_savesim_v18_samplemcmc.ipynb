# %% [markdown]
# # Simulated base inference of SEEG signals using 2D VEP model

# %%
import os
import sys
import time
import errno
import time
import timeit


import numpy as np
import scipy as scp


import numba
from numba import jit

import matplotlib.pyplot as plt
from matplotlib import colors, cm

# %%
import torch
import sbi 

import sbi.inference
from sbi.inference.base import infer

from sbi.simulators import linear_gaussian

from sbi.inference import SNPE, SNLE, SNRE, infer, prepare_for_sbi ,simulate_for_sbi
from sbi.inference.posteriors.base_posterior import NeuralPosterior

import sbi.utils as utils
from sbi.utils.get_nn_models import posterior_nn
from sbi.analysis import ActiveSubspace, pairplot

# %%
from typing import Any, Callable, Dict, List, Optional, Tuple, Union, cast

# %%
from sklearn.metrics import confusion_matrix
from BVEP_SME import SME_labels, SEM_violinplot, plot_confusion_matrix, plot_zscore_shrinkage, plot_roc_curve, true_node_binary, estimated_node_binary, SME_accuracy

# %%
from report_metrics import LSE, Err, RMSE, LSE_obs, z_score, shrinkage

# %%
import warnings
warnings.simplefilter("ignore")

# %%
# %pylab inline
#%matplotlib notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print('Running on numpy: v{}'.format(np.version.version))
print('Running on torch: v{}'.format(torch.__version__))
print('Running on sbi: v{}'.format(sbi.__version__))
# Out:
# Running on numpy: v1.21.5
# Running on torch: v1.10.2+cu102
# Running on sbi: v0.18.0

# %%
cwd = os.getcwd()
cwd
# Out:
# '/data/SBI/VEP_SBI-master'

# %%
Res_dir='Res_BVEP_ode_sbi_maf_sourcelevel_onset_patient1_savesim_v18_samplemcmc'

# %% [markdown]
# ### Constants

# %%
I1=3.1
eta_c=-2.05        
delta_eta=1.0                  
prior_std =1.0
sd_thr=0.8

# %% [markdown]
# # Patient CJ

# %%
cwd = os.getcwd()
cwd
# Out:
# '/data/SBI/VEP_SBI-master'

# %% [markdown]
# ## Structural Connectivity and Gain Matrices

# %%
weights = np.loadtxt(os.path.join(cwd+"/ExperimentalData_CJ", "weights.txt"))

# %%
# normalize Connectome
weights = weights/np.max(weights)
num_regions = len(weights)

# %%
weights.min(), weights.max()
# Out:
# (0.0, 1.0)

# %%
plt.figure(figsize=(8, 8))
norm = colors.LogNorm(1e-7, weights.max())
im = plt.imshow(weights,norm=norm,cmap=cm.jet)
plt.colorbar(im, fraction=0.046, pad=0.04)
plt.gca().set_title('Strcutural Connectivity', fontsize=24.0)
plt.ylabel('#Regions', fontsize=22.0)
plt.xlabel('#Regions', fontsize=22.0)

plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SCMatrix.png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SCMatrix.svg"), dpi=800)
plt.show()

# %% [markdown]
# ## ROIs chosen as Epileptogenic/propagation zones

# %%
hz_val=-3.65
pz_val=-2.4
ez_val=-1.6

ez_idx = np.array([6, 34],  dtype=np.int32)
pz_wplng_idx = np.array([5,11], dtype=np.int32)
pz_kplng_idx = np.array([27], dtype=np.int32)
pz_idx = np.append(pz_kplng_idx, pz_wplng_idx)

# %%
#Here, confidential medical information
weights[np.ix_(pz_kplng_idx, ez_idx)] = 4.0
weights[np.ix_(pz_wplng_idx, ez_idx)] = 1.0

weights[np.diag_indices(weights.shape[0])] = 0

# %%
SC=weights
SC.shape
# Out:
# (84, 84)

# %% [markdown]
# ### Simulator

# %%
from BVEP_Simulator import VEP2Dmodel

# %% [markdown]
# ### some simulations for  sanity check

# %%
T = 14.0
dt=0.1
ts = np.arange(0, T + dt, dt)

# %%
nt=ts.shape[0]
nt
# Out:
# 141

# %%
nn=SC.shape[0]
nn
# Out:
# 84

# %%
ns=nn
ns
# Out:
# 84

# %%
tau=10.
sigma=0*10e-1
constants = np.array([tau, sigma])
constants
# Out:
# array([10.,  0.])

# %%
eta_true = np.ones(nn)*hz_val
eta_true[ez_idx] = ez_val
eta_true[pz_idx] = pz_val

# %%
K_true=1.

# %%
x_init=-2.5
z_init=3.5
init_conditions = np.array([x_init, z_init])

# %%
params_true = np.append(eta_true, K_true)
params_true.shape
# Out:
# (85,)

# %%
start_time = time.time()
Sim = VEP2Dmodel(params_true, constants, init_conditions, dt, ts, SC)
print(" single sim (sec) takes:" , (time.time() - start_time))
# Out:
#  single sim (sec) takes: 5.331300735473633

# %%
start_time = time.time()
Sim = VEP2Dmodel(params_true, constants, init_conditions, dt, ts, SC)
print(" single sim (sec) takes:" , (time.time() - start_time))
# Out:
#  single sim (sec) takes: 0.0032324790954589844

# %%
X=Sim.reshape(nn, int(Sim.shape[0]/nn))
X.shape
# Out:
# (84, 141)

# %%
plt.figure(figsize=(10,16))
for i in range(0, nn):
    if i in ez_idx:
          plt.plot(X[i,:]+i, 'r', lw=3)
    elif i in pz_idx:
          plt.plot(X[i,:]+i, 'y', lw=3)
    else:  
          plt.plot(X[i,:]+i, 'g')
plt.yticks(np.r_[0:nn]-2, np.r_[0:nn],fontsize=10)
plt.xticks(fontsize=16)
plt.title("Source brain activity",fontsize=18)
plt.xlabel('Time',fontsize=22)
plt.ylabel('Brain Regions#',fontsize=22)
plt.show()

# %%
plt.plot(X.T);

# %% [markdown]
# ### Data features

# %%
X.shape
# Out:
# (84, 141)

# %%
X_area = np.trapz(X, dx=0.0001)
X_area.shape
# Out:
# (84,)

# %%
plt.figure(figsize=(18, 4))
plt.bar(np.arange(1,X_area.shape[0]+1), -X_area, color='black', alpha=0.3);
plt.xlabel('Brain regions', fontsize=22)
plt.ylabel('Source activity envelope power', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"Source_envelop_power.png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"Source_envelop_power.svg"), dpi=800)
plt.show()

# %%
X_pwr = np.sum((X*X), axis=1)
X_pwr_n = 1-(X_pwr/ X_pwr.max())

# %%
plt.figure(figsize=(18, 4))
plt.bar(np.arange(1,X_pwr.shape[0]+1), X_pwr_n, color='black', alpha=0.3);
plt.xlabel('Brain regions', fontsize=24)
plt.ylabel('Source activity power', fontsize=24)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"Source_envelop_power_normalize.png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"Source_envelop_power_normalize.svg"), dpi=800)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.subplot(211)
plt.plot(X.T, linewidth=4, alpha=0.2);
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source signals', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)

plt.subplot(212)
plt.bar(np.arange(1,X_pwr_n.shape[0]+1), X_pwr_n, color='r', alpha=0.2)
#plt.bar(np.arange(1,Seeg_area.shape[0]+1), Seeg_area, color='black', alpha=0.3);
plt.xlabel('Brain regions', fontsize=22)
plt.ylabel('Source activity envelop power', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.tight_layout()
plt.show()

# %%
from BVEP_stat_summary import calculate_summary_statistics_features

# %%
nn, ns, nt
# Out:
# (84, 84, 141)

# %%
_=calculate_summary_statistics_features(X.reshape(-1), nn, nt, dt, ts, features=['seizures_onset'])
num_features=_.shape[0]
print('feature shape:', num_features)
# Out:
# feature shape: 588

# %%
num_params=nn+1
num_params
# Out:
# 85

# %% [markdown]
# ### 1. Simulator wrapper

# %%
def VEP2Dmodel_source_simulator_wrapper(params):

    params = np.asarray(params)
    
    # time step
    T = 14.0
    dt=0.1
    ts = np.arange(0, T + dt, dt)

    # fixed parameters
    tau=10.
    sigma=0*10e-1
    constants = np.array([tau, sigma])
    
    nn=SC.shape[0]
    ns=nn
    nt=ts.shape[0]

    # initial conditions
    x_init=-2.5
    z_init=3.5
    init_conditions = np.array([x_init, z_init])
    
    Sim = VEP2Dmodel(params, constants, init_conditions, dt, ts, SC)

    #Source_signal=Sim.reshape(nn, int(Sim.shape[0]/nn))

    #summstats = torch.as_tensor(calculate_summary_statistics_features(Source_signal.reshape(-1),  nn, nt, dt, ts, features=['seizures_onset']))

    return Sim

# %% [markdown]
# ### 2. Prior over model parameters

# %%
nn+1
# Out:
# 85

# %%
prior_min_eta=-5*np.ones(nn)
prior_min_K=0*np.ones(1)

prior_max_eta=-1*np.ones(nn)
prior_max_K=2*np.ones(1)

# %%
prior_min=np.append(prior_min_eta, prior_min_K)
prior_max=np.append(prior_max_eta, prior_max_K)

# %%
prior_min.shape, prior_max.shape
# Out:
# ((85,), (85,))

# %%
prior = utils.torchutils.BoxUniform(low=torch.as_tensor(prior_min), high=torch.as_tensor(prior_max))

# %%
prior.sample().shape, prior.batch_shape, prior.event_shape
# Out:
# (torch.Size([85]), torch.Size([]), torch.Size([85]))

# %% [markdown]
# ### 3. Simulation and inference

# %%
num_sim=10000

# %%
# start_time = time.time()

# posterior = infer(VEP2Dmodel_source_simulator_wrapper, prior, method='SNPE',  num_simulations=10000, num_workers=1)

# print ("-"*60)
# print("--- %s seconds ---" % (time.time() - start_time))

# %%
mysavepath = os.path.join(Res_dir, 'output_sim/simulated_theta_x.npz')
mysavepath
# Out:
# 'Res_BVEP_ode_sbi_maf_sourcelevel_onset_patient1_savesim_v18_samplemcmc/output_sim/simulated_theta_x.npz'

# %%
def save_sims(simulator: Callable, prior, mysavepath, num_simulations: int):

    simulator, prior = prepare_for_sbi(simulator, prior)
    
    theta, x = simulate_for_sbi(
        simulator=simulator,
        proposal=prior,
        num_simulations=num_simulations,
        show_progress_bar=True,)
    
    #print(theta,flush=True)
    print( 'theta shape:',theta.shape,flush=True)
    #print(x,flush=True)
    print('data shape:', x.shape,flush=True)

    np.savez(mysavepath,theta=theta,x=x)

# %%
start_time = time.time()

save_sims(VEP2Dmodel_source_simulator_wrapper, prior, mysavepath, num_simulations=1)

print ("-"*60)
print("--- one sim took: %s seconds ---" % (time.time() - start_time))
# Out:
# theta shape: torch.Size([1, 85])
# data shape: torch.Size([1, 11844])
# ------------------------------------------------------------
# --- one sim took: 3.989795207977295 seconds ---

# %%
start_time = time.time()

save_sims(VEP2Dmodel_source_simulator_wrapper, prior, mysavepath, num_simulations=1)

print ("-"*60)
print("--- one sim with JIT took: %s seconds ---" % (time.time() - start_time))
# Out:
# theta shape: torch.Size([1, 85])
# data shape: torch.Size([1, 11844])
# ------------------------------------------------------------
# --- one sim with JIT took: 0.012267827987670898 seconds ---

# %%
start_time = time.time()

save_sims(VEP2Dmodel_source_simulator_wrapper, prior, mysavepath, num_simulations=num_sim)

print ("-"*60)
print("---all simulations took:  %s seconds ---" % (time.time() - start_time))
# Out:
# Running 10000 simulations.:   0%|          | 0/10000 [00:00<?, ?it/s]
# theta shape: torch.Size([10000, 85])
# data shape: torch.Size([10000, 11844])
# ------------------------------------------------------------
# ---all simulations took:  34.61001467704773 seconds ---

# %% [markdown]
# ### Load simulations and calculate features

# %%
sim_deja=np.load(mysavepath)

# %%
theta_deja=sim_deja['theta']
x_deja=sim_deja['x']

# %%
print( 'theta shape:',theta_deja.shape,flush=True)
print('data shape:', x_deja.shape,flush=True)
# Out:
# theta shape: (10000, 85)
# data shape: (10000, 11844)

# %%
x_deja_features=np.zeros((num_sim,num_features))
theta_deja_features=np.zeros((num_sim,num_params))

# %%
print( 'theta shape:',theta_deja_features.shape,flush=True)
print('data frature shape:', x_deja_features.shape,flush=True)
# Out:
# theta shape: (10000, 85)
# data frature shape: (10000, 588)

# %%
start_time = time.time()

for i in range(num_sim):
    theta_deja_features[i,:]=theta_deja[i,:]
    x_deja_features[i,:]=calculate_summary_statistics_features(x_deja[i,:].reshape(-1), nn, nt, dt, ts, features=['seizures_onset'])

print ("-"*60)
print("---feature calculation took:  %s seconds ---" % (time.time() - start_time))
# Out:
# ------------------------------------------------------------
# ---feature calculation took:  22.067745447158813 seconds ---

# %%
print( 'theta deja shape:',theta_deja_features.shape,flush=True)
print('data deja feature shape:', x_deja_features.shape,flush=True)
# Out:
# theta deja shape: (10000, 85)
# data deja feature shape: (10000, 588)

# %%
np.isnan(np.sum(x_deja_features))
# Out:
# False

# %%
x = np.array(x_deja_features, dtype='float32')
x     = torch.as_tensor(x)

theta = np.array(theta_deja_features, dtype='float32')
theta = theta.reshape(theta.shape[0],num_params)
theta = torch.as_tensor(theta)

# %%
print( 'theta shape:',theta.shape,flush=True)
print('data feature shape:', x.shape,flush=True)
# Out:
# theta shape: torch.Size([10000, 85])
# data feature shape: torch.Size([10000, 588])

# %% [markdown]
# ### Inference

# %%
def myinfer_SNPE(prior, theta, x):
    
    inference = SNPE(prior, density_estimator='maf', device='cpu')
    _ = inference.append_simulations(theta, x).train()
    posterior = inference.build_posterior(sample_with='mcmc')

    return posterior

# %%
start_time = time.time()

posterior = myinfer_SNPE(prior, theta, x)

print ("-"*60)
print("--- Training neural network took: %s seconds ---" % (time.time() - start_time))
# Out:
#  Neural network successfully converged after 535 epochs.------------------------------------------------------------
# --- Training neural network took: 1094.6065468788147 seconds ---

# %% [markdown]
# ### Data

# %%
obs_source =VEP2Dmodel(params_true, constants, init_conditions, dt, ts, SC)
obs_source=obs_source.reshape(nn, int(obs_source.shape[0]/nn))

# %%
obs_summary_statistics=calculate_summary_statistics_features(obs_source.reshape(-1),  nn, nt, dt, ts, features=['seizures_onset'])

# %%
obs_source.shape, obs_summary_statistics.shape
# Out:
# ((84, 141), (588,))

# %%
y_obs=obs_source
y_obs.shape
# Out:
# (84, 141)

# %%
plt.figure(figsize=(10,16))
for i in range(0, nn):
    if i in ez_idx:
          plt.plot(obs_source[i,:]+i, 'r', lw=3)
    elif i in pz_idx:
          plt.plot(obs_source[i,:]+i, 'y', lw=3)
    else:  
          plt.plot(obs_source[i,:]+i, 'g')
plt.yticks(np.r_[0:nn]-2, np.r_[0:nn],fontsize=10)
plt.xticks(fontsize=16)
plt.title("Source brain activity",fontsize=18)
plt.xlabel('Time',fontsize=22)
plt.ylabel('Brain Regions#',fontsize=22)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs_source_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs_source_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %% [markdown]
# ### Posterior

# %%
from sklearn.metrics import confusion_matrix
from BVEP_SME import SME_labels, SEM_violinplot, plot_confusion_matrix, plot_zscore_shrinkage, plot_roc_curve, true_node_binary, estimated_node_binary, SME_accuracy

# %%
nodes=np.r_[0:nn]

# %%
num_samples=200

# %%
start_time = time.time()

posterior_samples = posterior.sample((num_samples,), obs_summary_statistics).numpy()

print ("-"*60)
print("--- sampling took: %s seconds ---" % (time.time() - start_time))
# Out:
# Running 1 MCMC chains in 1 batches.:   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Tuning bracket width...:   0%|          | 0/50 [00:00<?, ?it/s]
# Tuning bracket width...:   0%|          | 0/50 [00:16<?, ?it/s]
# Tuning bracket width...:   2%|▏         | 1/50 [11:42<9:34:02, 702.90s/it]
# Tuning bracket width...:   4%|▍         | 2/50 [11:43<3:51:58, 289.97s/it]
# Tuning bracket width...:   6%|▌         | 3/50 [11:44<2:03:46, 158.00s/it]
# Tuning bracket width...:   8%|▊         | 4/50 [11:45<1:13:38, 96.06s/it]
# Tuning bracket width...:  10%|█         | 5/50 [11:46<46:20, 61.79s/it]
# Tuning bracket width...:  12%|█▏        | 6/50 [11:47<30:10, 41.15s/it]
# Tuning bracket width...:  14%|█▍        | 7/50 [11:49<20:06, 28.06s/it]
# Tuning bracket width...:  16%|█▌        | 8/50 [11:50<13:38, 19.49s/it]
# Tuning bracket width...:  18%|█▊        | 9/50 [11:51<09:24, 13.76s/it]
# Tuning bracket width...:  20%|██        | 10/50 [11:52<06:35,  9.89s/it]
# Tuning bracket width...:  22%|██▏       | 11/50 [11:53<04:41,  7.21s/it]
# Tuning bracket width...:  24%|██▍       | 12/50 [11:54<03:24,  5.38s/it]
# Tuning bracket width...:  26%|██▌       | 13/50 [11:56<02:31,  4.10s/it]
# Tuning bracket width...:  28%|██▊       | 14/50 [11:57<01:55,  3.22s/it]
# Tuning bracket width...:  30%|███       | 15/50 [11:58<01:31,  2.61s/it]
# Tuning bracket width...:  32%|███▏      | 16/50 [11:59<01:13,  2.17s/it]
# Tuning bracket width...:  34%|███▍      | 17/50 [12:00<01:01,  1.86s/it]
# Tuning bracket width...:  36%|███▌      | 18/50 [12:01<00:52,  1.65s/it]

#
#   0%|          | 0/10 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/10 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/10 [00:13<?, ?it/s]
# Generating samples:  20%|██        | 2/10 [00:21<01:24, 10.62s/it]
# Generating samples:  30%|███       | 3/10 [00:31<01:14, 10.58s/it]
# Generating samples:  40%|████      | 4/10 [00:42<01:03, 10.63s/it]
# Generating samples:  50%|█████     | 5/10 [00:53<00:53, 10.73s/it]
# Generating samples:  60%|██████    | 6/10 [01:03<00:42, 10.66s/it]
# Generating samples:  70%|███████   | 7/10 [01:14<00:32, 10.67s/it]
# Generating samples:  80%|████████  | 8/10 [01:25<00:21, 10.75s/it]
# Generating samples:  90%|█████████ | 9/10 [01:36<00:10, 10.80s/it]
# Generating samples: 100%|██████████| 10/10 [01:47<00:00, 10.72s/it]
#
#   0%|          | 0/200 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/200 [00:12<?, ?it/s]
# Generating samples:   1%|          | 2/200 [00:21<36:05, 10.94s/it]
# Generating samples:   2%|▏         | 3/200 [00:32<35:42, 10.88s/it]
# Generating samples:   2%|▏         | 4/200 [00:44<36:20, 11.13s/it]
# Generating samples:   2%|▎         | 5/200 [00:55<36:07, 11.12s/it]
# Generating samples:   3%|▎         | 6/200 [01:06<35:35, 11.01s/it]
# Generating samples:   4%|▎         | 7/200 [01:16<34:58, 10.87s/it]
# Generating samples:   4%|▍         | 8/200 [01:27<34:25, 10.76s/it]
# Generating samples:   4%|▍         | 9/200 [01:38<34:19, 10.78s/it]
# Generating samples:   5%|▌         | 10/200 [01:49<34:21, 10.85s/it]
# Generating samples:   6%|▌         | 11/200 [02:00<34:18, 10.89s/it]
# Generating samples:   6%|▌         | 12/200 [02:11<34:15, 10.93s/it]
# Generating samples:   6%|▋         | 13/200 [02:21<33:38, 10.79s/it]
# Generating samples:   7%|▋         | 14/200 [02:32<33:24, 10.78s/it]
# Generating samples:   8%|▊         | 15/200 [02:42<32:59, 10.70s/it]
# Generating samples:   8%|▊         | 16/200 [02:53<32:53, 10.73s/it]
# Generating samples:   8%|▊         | 17/200 [03:04<33:03, 10.84s/it]
# Generating samples:   9%|▉         | 18/200 [03:15<32:32, 10.73s/it]
# Generating samples:  10%|▉         | 19/200 [03:25<32:14, 10.69s/it]
# Generating samples:  10%|█         | 20/200 [03:36<31:52, 10.62s/it]
# Generating samples:  10%|█         | 21/200 [03:46<31:45, 10.65s/it]
# Generating samples:  11%|█         | 22/200 [03:57<31:38, 10.67s/it]
# Generating samples:  12%|█▏        | 23/200 [04:08<31:47, 10.78s/it]
# Generating samples:  12%|█▏        | 24/200 [04:19<31:26, 10.72s/it]
# Generating samples:  12%|█▎        | 25/200 [04:29<31:15, 10.72s/it]
# Generating samples:  13%|█▎        | 26/200 [04:40<31:02, 10.70s/it]
# Generating samples:  14%|█▎        | 27/200 [04:51<30:37, 10.62s/it]
# Generating samples:  14%|█▍        | 28/200 [05:02<30:48, 10.74s/it]
# Generating samples:  14%|█▍        | 29/200 [05:12<30:43, 10.78s/it]
# Generating samples:  15%|█▌        | 30/200 [05:23<30:29, 10.76s/it]
# Generating samples:  16%|█▌        | 31/200 [05:34<30:19, 10.77s/it]
# Generating samples:  16%|█▌        | 32/200 [05:45<30:20, 10.84s/it]
# Generating samples:  16%|█▋        | 33/200 [05:56<29:58, 10.77s/it]
# Generating samples:  76%|███████▋  | 153/200 [27:30<08:24, 10.74s/it]
# Generating samples:  77%|███████▋  | 154/200 [27:41<08:15, 10.76s/it]
# Generating samples:  78%|███████▊  | 155/200 [27:52<08:03, 10.74s/it]
# Generating samples:  78%|███████▊  | 156/200 [28:03<07:53, 10.76s/it]
# Generating samples:  78%|███████▊  | 157/200 [28:13<07:43, 10.77s/it]
# Generating samples:  79%|███████▉  | 158/200 [28:24<07:31, 10.75s/it]
# Generating samples:  80%|███████▉  | 159/200 [28:34<07:17, 10.67s/it]
# Generating samples:  80%|████████  | 160/200 [28:45<07:06, 10.65s/it]
# Generating samples:  80%|████████  | 161/200 [28:56<06:58, 10.73s/it]
# Generating samples:  81%|████████  | 162/200 [29:07<06:46, 10.69s/it]
# Generating samples:  82%|████████▏ | 163/200 [29:17<06:36, 10.72s/it]
# Generating samples:  82%|████████▏ | 164/200 [29:28<06:27, 10.75s/it]
# Generating samples:  82%|████████▎ | 165/200 [29:39<06:17, 10.78s/it]
# Generating samples:  83%|████████▎ | 166/200 [29:50<06:06, 10.79s/it]
# Generating samples:  84%|████████▎ | 167/200 [30:00<05:53, 10.71s/it]
# Generating samples:  84%|████████▍ | 168/200 [30:11<05:44, 10.76s/it]
# Generating samples:  84%|████████▍ | 169/200 [30:22<05:34, 10.80s/it]
# Generating samples:  85%|████████▌ | 170/200 [30:33<05:20, 10.67s/it]
# Generating samples:  86%|████████▌ | 171/200 [30:43<05:08, 10.64s/it]
# Generating samples:  86%|████████▌ | 172/200 [30:54<04:57, 10.64s/it]
# Generating samples:  86%|████████▋ | 173/200 [31:04<04:46, 10.63s/it]
# Generating samples:  87%|████████▋ | 174/200 [31:15<04:37, 10.68s/it]
# Generating samples:  88%|████████▊ | 175/200 [31:26<04:27, 10.70s/it]
# Generating samples:  88%|████████▊ | 176/200 [31:37<04:17, 10.72s/it]
# Generating samples:  88%|████████▊ | 177/200 [31:47<04:06, 10.73s/it]
# Generating samples:  89%|████████▉ | 178/200 [31:58<03:55, 10.70s/it]
# Generating samples:  90%|████████▉ | 179/200 [32:09<03:45, 10.72s/it]
# Generating samples:  90%|█████████ | 180/200 [32:20<03:37, 10.89s/it]
# Generating samples:  90%|█████████ | 181/200 [32:31<03:27, 10.92s/it]
# Generating samples:  91%|█████████ | 182/200 [32:42<03:14, 10.80s/it]
# Generating samples:  92%|█████████▏| 183/200 [32:52<03:02, 10.75s/it]
# Generating samples:  92%|█████████▏| 184/200 [33:03<02:51, 10.69s/it]
# Generating samples:  92%|█████████▎| 185/200 [33:13<02:39, 10.65s/it]
# Generating samples:  93%|█████████▎| 186/200 [33:25<02:32, 10.90s/it]
# Generating samples:  94%|█████████▎| 187/200 [33:35<02:20, 10.78s/it]
# Generating samples:  94%|█████████▍| 188/200 [33:46<02:09, 10.77s/it]
# Generating samples:  94%|█████████▍| 189/200 [33:57<01:57, 10.71s/it]
# Generating samples:  95%|█████████▌| 190/200 [34:08<01:47, 10.77s/it]
# Generating samples:  96%|█████████▌| 191/200 [34:19<01:37, 10.84s/it]
# Generating samples:  96%|█████████▌| 192/200 [34:29<01:26, 10.87s/it]
# Generating samples:  96%|█████████▋| 193/200 [34:40<01:16, 10.87s/it]
# Generating samples:  97%|█████████▋| 194/200 [34:51<01:04, 10.79s/it]
# Generating samples:  98%|█████████▊| 195/200 [35:01<00:53, 10.69s/it]
# Generating samples:  98%|█████████▊| 196/200 [35:12<00:42, 10.68s/it]
# Generating samples:  98%|█████████▊| 197/200 [35:23<00:31, 10.65s/it]
# Generating samples:  99%|█████████▉| 198/200 [35:33<00:21, 10.66s/it]
# Generating samples: 100%|█████████▉| 199/200 [35:44<00:10, 10.60s/it]
# Generating samples: 100%|██████████| 200/200 [35:55<00:00, 10.78s/it]
# Running 1 MCMC chains in 1 batches.: 100%|██████████| 1/1 [50:19<00:00, 3019.31s/it]
# ------------------------------------------------------------
# --- sampling took: 3019.538187980652 seconds ---

# %%
posterior_samples.shape, params_true.shape
# Out:
# ((200, 85), (85,))

# %%
np.save(os.path.join(cwd+'/'+str(Res_dir), 'BVEP_ode_sbi_sourcelevel_patient1_posteriorsamples.npy') , posterior_samples)

# %%
eta_posterior=posterior_samples[:,:-1]
K_posterior=posterior_samples[:,-1]

# %%
K_posterior.mean(), K_posterior.std()
# Out:
# (1.1747657, 0.40669352)

# %%
eta_c=-1.95
delta_eta=1.0

# %%
plt.figure(figsize=(15,4))
SEM_violinplot(nn, eta_true, ez_idx, pz_idx, eta_posterior, eta_c, delta_eta )
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_InferredExcitability_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_InferredExcitability_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
plt.figure(figsize=(4,4))
parts= plt.violinplot(K_posterior, widths=0.7, showmeans=True, showextrema=True);
plt.plot(1,params_true[-1] ,'o', color='k', alpha=0.9, markersize=8)
plt.ylabel(' Posterior ' +r'${(K)}$', fontsize=24);  
plt.xlabel(r'${K}$', fontsize=24); 
plt.yticks(fontsize=16)
plt.xticks([])
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_InferredCoupling_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_InferredCoupling_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
estimated_posterior=np.percentile(posterior_samples, [50], axis=0).reshape(-1)

# %%
y_fit_source =VEP2Dmodel(estimated_posterior, constants, init_conditions, dt, ts, SC)

yfit_source=y_fit_source.reshape(nn, int(y_fit_source.shape[0]/nn))

# %%
y_fit=yfit_source
y_fit.shape
# Out:
# (84, 141)

# %%
np.save(os.path.join(cwd+'/'+str(Res_dir), 'BVEP_ode_sbi_sourcelevel_patient1_y_obs.npy') , y_obs)
np.save(os.path.join(cwd+'/'+str(Res_dir), 'BVEP_ode_sbi_sourcelevel_patient1_y_fit.npy') , y_fit)

# %%
Rois=np.array([1, 5, 6, 11, 27, 34, 50])

plt.figure(figsize=(10,4))
for roi in Rois:
    plt.plot(y_obs.T[:,roi], '.')
    plt.plot(y_fit.T[:,roi] )
plt.title("Observation vs prediction",fontsize=15)
plt.xlabel('Time', fontsize=22)
plt.ylabel('SEEG signals', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.show()

# %%
plt.figure(figsize=(12,4))

plt.subplot(121);
plt.plot(y_obs.T)
plt.title("Simulated source data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)

plt.subplot(122)
plt.plot(y_fit.T)
plt.title(" Predicted Source data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_FittedBVEP_ode_observation_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_FittedBVEP_ode_observation_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
plt.figure(figsize=(14, 4))
plt.subplot(121);
plt.imshow(y_obs, aspect='auto', interpolation='bilinear',  origin='lower', cmap='Reds')
plt.title("Simulated Source  data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.colorbar();

plt.subplot(122)
plt.imshow(y_fit, aspect='auto', interpolation='bilinear',  origin='lower', cmap='Reds')
plt.title(" Predicted Source  data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0) 
plt.colorbar();

plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_ImshowFittedBVEP_ode_observation_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_ImshowFittedBVEP_ode_observation_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
eta_true.shape, eta_posterior.shape
# Out:
# ((84,), (200, 84))

# %%
true_labels_nodes,est_labels_nodes =SME_labels(eta_true, eta_posterior.transpose(), eta_c, delta_eta)

# %%
Confusion_matrix_values= confusion_matrix(true_labels_nodes, est_labels_nodes, labels=["EZ", "PZ", "HZ"])
print('Confusion_matrix_values= \n', Confusion_matrix_values)
# Out:
# Confusion_matrix_values=
#  [[ 2  0  0]
#  [ 0  3  0]
#  [ 0  0 79]]

# %%
plt.figure(figsize=(8, 6))
plot_confusion_matrix(Confusion_matrix_values, ["EZ", "PZ", "HZ"])
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_ConfusionMatrix_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_ConfusionMatrix_K_"+str(K_true)+".svg"), dpi=800)
plt.tight_layout()
plt.show()

# %%
np.sum(np.std(eta_posterior, axis=0))
# Out:
# 5.885426

# %%
from report_metrics import LSE, Err, RMSE, LSE_obs, z_score, shrinkage

# %%
eta_est_mu=np.mean(eta_posterior, axis=0)
eta_est_std=np.std(eta_posterior, axis=0)

# %%
b=-7
a=-1
prior_std =np.sqrt((1/12)*(b-a)**2)

# %%
def plot_zscore_shrinkage(nodes, eta_true, eta_est_mu, eta_est_std, prior_std):
    z_score_eta=z_score(eta_true, eta_est_mu, eta_est_std)
    colors= np.random.rand(z_score_eta.shape[0])
    plt.scatter(shrinkage([prior_std]*nodes.shape[0], eta_est_std), z_score_eta ,s=120, c='blue')
    plt.xlabel("Posterior shrinkages", fontsize=24)
    plt.ylabel("Posterior z-scores", fontsize=24)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
plot_zscore_shrinkage(nodes, eta_true, eta_est_mu, eta_est_std, prior_std)
plt.axis((-.1,1.1,-2,20))
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_zscore_shrinkage_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_zscore_shrinkage_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
Err(eta_true, eta_est_mu), RMSE(eta_true, eta_est_mu)
# Out:
# (3.4743188381195065, 0.05673410238302765)

# %%
Err(y_obs, y_fit), RMSE(y_obs, y_fit)
# Out:
# (167.06910624149413, 0.037484255853996666)

# %%
shrinkage([prior_std]*nodes.shape[0], eta_est_std).shape
# Out:
# (84,)

# %%
from sklearn import metrics
from itertools import cycle
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize

# %%
n_classes=3
node_classes=['HZ', 'PZ', 'EZ']

# %%
true_nodes=true_node_binary(true_labels_nodes)
estimated_nodes=estimated_node_binary(est_labels_nodes)

# %%
y_true=label_binarize(true_nodes, classes=[0, 1, 2])
y_pred=label_binarize(estimated_nodes, classes=[0, 1, 2])

# %%
y_true.shape, y_pred.shape
# Out:
# ((84, 3), (84, 3))

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()


for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])
    
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = metrics.roc_curve(y_true.ravel(), y_pred.ravel())
roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])    


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = metrics.auc(fpr["macro"], tpr["macro"])

# %%
# Plot all ROC curves
plt.figure()

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
lw=2

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class '+ str(node_classes[i])+' (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-.01, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=22)
plt.ylabel('True Positive Rate', fontsize=22)
plt.title('ROC for amortized inference of SEEG', fontsize=18)
plt.legend(loc="lower right")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"ROC_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"ROC_K_"+str(K_true)+".png"), dpi=800)
plt.show()

# %%
fpr
# Out:
# {0: array([0., 0., 1.]),
#  1: array([0., 0., 1.]),
#  2: array([0., 0., 1.]),
#  'micro': array([0., 0., 1.]),
#  'macro': array([0., 1.])}

# %%
tpr
# Out:
# {0: array([0., 1., 1.]),
#  1: array([0., 1., 1.]),
#  2: array([0., 1., 1.]),
#  'micro': array([0., 1., 1.]),
#  'macro': array([1., 1.])}

# %%
roc_auc["micro"], roc_auc["macro"]
# Out:
# (1.0, 1.0)

# %% [markdown]
# ### Another Data set

# %%
hz_val=-3.65
pz_val=-2.5
ez_val=-1.7


ez_idx = np.array([7, 29],  dtype=np.int32)
pz_wplng_idx = np.array([6, 9, 28], dtype=np.int32)
pz_kplng_idx = np.array([27], dtype=np.int32)
pz_idx = np.append(pz_kplng_idx, pz_wplng_idx)

# %%
eta_true = np.ones(nn)*hz_val
eta_true[ez_idx] = ez_val
eta_true[pz_idx] = pz_val

# %%
K_true=1.

# %%
x_init=-2.5
z_init=3.5
init_conditions = np.array([x_init, z_init])

# %%
params_true = np.append(eta_true, K_true)
params_true.shape
# Out:
# (85,)

# %%
obs_source =VEP2Dmodel(params_true, constants, init_conditions, dt, ts, SC)
obs_source=obs_source.reshape(nn, int(obs_source.shape[0]/nn))

# %%
plt.figure(figsize=(10,16))
for i in range(0, nn):
    if i in ez_idx:
          plt.plot(obs_source[i,:]+i, 'r', lw=3)
    elif i in pz_idx:
          plt.plot(obs_source[i,:]+i, 'y', lw=3)
    else:  
          plt.plot(obs_source[i,:]+i, 'g')
plt.yticks(np.r_[0:nn]-2, np.r_[0:nn],fontsize=10)
plt.xticks(fontsize=16)
plt.title("Source brain activity",fontsize=18)
plt.xlabel('Time',fontsize=22)
plt.ylabel('Brain Regions#',fontsize=22)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_source_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_source_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
obs_summary_statistics=calculate_summary_statistics_features(obs_source.reshape(-1),  nn, nt, dt, ts, features=['seizures_onset'])

# %%
obs_source.shape, obs_summary_statistics.shape
# Out:
# ((84, 141), (588,))

# %%
y_obs=obs_source
y_obs.shape
# Out:
# (84, 141)

# %%
plt.figure(figsize=(10,6))
plt.plot(obs_source.T)
plt.title("Source activity signals",fontsize=15)
plt.xlabel('Time',fontsize=12)
plt.ylabel('Regions#',fontsize=12)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_seeg_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_seeg_K_"+str(K_true)+".svg"), dpi=800)

# %% [markdown]
# ### Posterior

# %%
nodes=np.r_[0:nn]

# %%
num_samples=200

# %%
start_time = time.time()

posterior_samples = posterior.sample((num_samples,), obs_summary_statistics).numpy()

print ("-"*60)
print("--- sampling took: %s seconds ---" % (time.time() - start_time))
# Out:
# Running 1 MCMC chains in 1 batches.:   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Tuning bracket width...:   0%|          | 0/50 [00:00<?, ?it/s]
# Tuning bracket width...:   0%|          | 0/50 [00:12<?, ?it/s]
# Tuning bracket width...:   2%|▏         | 1/50 [10:48<8:49:22, 648.21s/it]
# Tuning bracket width...:   4%|▍         | 2/50 [10:49<3:33:57, 267.45s/it]
# Tuning bracket width...:   6%|▌         | 3/50 [10:50<1:54:09, 145.73s/it]
# Tuning bracket width...:   8%|▊         | 4/50 [10:50<1:07:54, 88.59s/it]
# Tuning bracket width...:  10%|█         | 5/50 [10:52<42:45, 57.01s/it]
# Tuning bracket width...:  12%|█▏        | 6/50 [10:53<27:51, 37.99s/it]
# Tuning bracket width...:  14%|█▍        | 7/50 [10:54<18:34, 25.92s/it]
# Tuning bracket width...:  16%|█▌        | 8/50 [10:55<12:36, 18.02s/it]
# Tuning bracket width...:  18%|█▊        | 9/50 [10:56<08:42, 12.75s/it]
# Tuning bracket width...:  20%|██        | 10/50 [10:57<06:06,  9.16s/it]
# Tuning bracket width...:  22%|██▏       | 11/50 [10:58<04:21,  6.72s/it]
# Tuning bracket width...:  24%|██▍       | 12/50 [10:59<03:10,  5.02s/it]
# Tuning bracket width...:  26%|██▌       | 13/50 [11:01<02:23,  3.87s/it]
# Tuning bracket width...:  28%|██▊       | 14/50 [11:02<01:49,  3.05s/it]
# Tuning bracket width...:  30%|███       | 15/50 [11:03<01:26,  2.48s/it]
# Tuning bracket width...:  32%|███▏      | 16/50 [11:04<01:10,  2.06s/it]
# Tuning bracket width...:  34%|███▍      | 17/50 [11:05<00:58,  1.77s/it]
# Tuning bracket width...:  36%|███▌      | 18/50 [11:06<00:50,  1.58s/it]
# Tuning bracket width...:  38%|███▊      | 19/50 [11:07<00:44,  1.43s/it]
# Tuning bracket width...:  40%|████      | 20/50 [11:08<00:39,  1.33s/it]
# Tuning bracket width...:  42%|████▏     | 21/50 [11:09<00:36,  1.27s/it]
# Tuning bracket width...:  44%|████▍     | 22/50 [11:11<00:34,  1.24s/it]
# Tuning bracket width...:  46%|████▌     | 23/50 [11:12<00:32,  1.21s/it]
# Tuning bracket width...:  48%|████▊     | 24/50 [11:13<00:30,  1.17s/it]
# Tuning bracket width...:  50%|█████     | 25/50 [11:14<00:28,  1.15s/it]
# Tuning bracket width...:  52%|█████▏    | 26/50 [11:15<00:27,  1.16s/it]
# Tuning bracket width...:  54%|█████▍    | 27/50 [11:16<00:25,  1.11s/it]
# Tuning bracket width...:  56%|█████▌    | 28/50 [11:17<00:23,  1.09s/it]
# Tuning bracket width...:  58%|█████▊    | 29/50 [11:18<00:22,  1.09s/it]
# Tuning bracket width...:  60%|██████    | 30/50 [11:19<00:21,  1.10s/it]
# Tuning bracket width...:  62%|██████▏   | 31/50 [11:20<00:20,  1.09s/it]
# Tuning bracket width...:  64%|██████▍   | 32/50 [11:22<00:19,  1.08s/it]
# Tuning bracket width...:  66%|██████▌   | 33/50 [11:23<00:18,  1.06s/it]
# Tuning bracket width...:  68%|██████▊   | 34/50 [11:24<00:17,  1.08s/it]
# Tuning bracket width...:  70%|███████   | 35/50 [11:25<00:16,  1.07s/it]
# Tuning bracket width...:  72%|███████▏  | 36/50 [11:26<00:15,  1.07s/it]
# Tuning bracket width...:  74%|███████▍  | 37/50 [11:27<00:13,  1.07s/it]
# Tuning bracket width...:  76%|███████▌  | 38/50 [11:28<00:12,  1.06s/it]
# Tuning bracket width...:  78%|███████▊  | 39/50 [11:29<00:11,  1.06s/it]
# Tuning bracket width...:  80%|████████  | 40/50 [11:30<00:10,  1.05s/it]
# Tuning bracket width...:  82%|████████▏ | 41/50 [11:31<00:09,  1.07s/it]
# Tuning bracket width...:  84%|████████▍ | 42/50 [11:32<00:08,  1.05s/it]
# Tuning bracket width...:  86%|████████▌ | 43/50 [11:33<00:07,  1.03s/it]
# Tuning bracket width...:  88%|████████▊ | 44/50 [11:34<00:06,  1.04s/it]
# Tuning bracket width...:  90%|█████████ | 45/50 [11:35<00:05,  1.04s/it]
# Tuning bracket width...:  92%|█████████▏| 46/50 [11:36<00:04,  1.03s/it]
# Tuning bracket width...:  94%|█████████▍| 47/50 [11:37<00:03,  1.07s/it]
# Tuning bracket width...:  96%|█████████▌| 48/50 [11:38<00:02,  1.09s/it]
# Tuning bracket width...:  98%|█████████▊| 49/50 [11:40<00:01,  1.10s/it]
# Tuning bracket width...: 100%|██████████| 50/50 [11:41<00:00, 14.03s/it]
#
#   0%|          | 0/10 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/10 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/10 [00:11<?, ?it/s]
# Generating samples:  20%|██        | 2/10 [00:20<01:22, 10.30s/it]
# Generating samples:  30%|███       | 3/10 [00:30<01:12, 10.31s/it]
# Generating samples:  40%|████      | 4/10 [00:41<01:01, 10.32s/it]
# Generating samples:  50%|█████     | 5/10 [00:51<00:51, 10.24s/it]
# Generating samples:  60%|██████    | 6/10 [01:02<00:41, 10.41s/it]
# Generating samples:  70%|███████   | 7/10 [01:12<00:31, 10.43s/it]
# Generating samples:  80%|████████  | 8/10 [01:23<00:20, 10.45s/it]
# Generating samples:  90%|█████████ | 9/10 [01:33<00:10, 10.43s/it]
# Generating samples: 100%|██████████| 10/10 [01:43<00:00, 10.36s/it]
#
#   0%|          | 0/200 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/200 [00:14<?, ?it/s]
# Generating samples:   1%|          | 2/200 [00:21<34:40, 10.51s/it]
# Generating samples:   2%|▏         | 3/200 [00:31<34:43, 10.57s/it]
# Generating samples:   2%|▏         | 4/200 [00:42<34:20, 10.51s/it]
# Generating samples:   2%|▎         | 5/200 [00:52<33:42, 10.37s/it]
# Generating samples:   3%|▎         | 6/200 [01:02<33:36, 10.39s/it]
# Generating samples:   4%|▎         | 7/200 [01:12<33:13, 10.33s/it]
# Generating samples:   4%|▍         | 8/200 [01:23<33:14, 10.39s/it]
# Generating samples:   4%|▍         | 9/200 [01:33<33:03, 10.38s/it]
# Generating samples:   5%|▌         | 10/200 [01:44<32:53, 10.39s/it]
# Generating samples:   6%|▌         | 11/200 [01:54<32:35, 10.35s/it]
# Generating samples:   6%|▌         | 12/200 [02:04<32:34, 10.40s/it]
# Generating samples:   6%|▋         | 13/200 [02:15<32:32, 10.44s/it]
# Generating samples:   7%|▋         | 14/200 [02:25<32:24, 10.45s/it]
# Generating samples:   8%|▊         | 15/200 [02:36<32:09, 10.43s/it]
# Generating samples:   8%|▊         | 16/200 [02:46<31:57, 10.42s/it]
# Generating samples:   8%|▊         | 17/200 [02:56<31:32, 10.34s/it]
# Generating samples:   9%|▉         | 18/200 [03:07<31:21, 10.34s/it]
# Generating samples:  10%|▉         | 19/200 [03:17<31:24, 10.41s/it]
# Generating samples:  10%|█         | 20/200 [03:28<31:40, 10.56s/it]
# Generating samples:  10%|█         | 21/200 [03:38<31:09, 10.44s/it]
# Generating samples:  11%|█         | 22/200 [03:49<30:58, 10.44s/it]
# Generating samples:  12%|█▏        | 23/200 [03:59<30:37, 10.38s/it]
# Generating samples:  12%|█▏        | 24/200 [04:09<30:23, 10.36s/it]
# Generating samples:  12%|█▎        | 25/200 [04:20<30:33, 10.48s/it]
# Generating samples:  13%|█▎        | 26/200 [04:31<30:30, 10.52s/it]
# Generating samples:  14%|█▎        | 27/200 [04:41<30:14, 10.49s/it]
# Generating samples:  14%|█▍        | 28/200 [04:51<29:54, 10.43s/it]
# Generating samples:  14%|█▍        | 29/200 [05:02<29:50, 10.47s/it]
# Generating samples:  15%|█▌        | 30/200 [05:12<29:32, 10.43s/it]
# Generating samples:  16%|█▌        | 31/200 [05:23<29:40, 10.53s/it]
# Generating samples:  16%|█▌        | 32/200 [05:33<29:22, 10.49s/it]
# Generating samples:  16%|█▋        | 33/200 [05:44<28:58, 10.41s/it]
# Generating samples:  17%|█▋        | 34/200 [05:54<28:33, 10.32s/it]
# Generating samples:  18%|█▊        | 35/200 [06:04<28:21, 10.31s/it]
# Generating samples:  18%|█▊        | 36/200 [06:15<28:22, 10.38s/it]
# Generating samples:  18%|█▊        | 37/200 [06:25<28:17, 10.41s/it]
# Generating samples:  19%|█▉        | 38/200 [06:36<28:10, 10.44s/it]
# Generating samples:  20%|█▉        | 39/200 [06:46<28:04, 10.46s/it]
# Generating samples:  20%|██        | 40/200 [06:57<27:50, 10.44s/it]
# Generating samples:  20%|██        | 41/200 [07:07<27:33, 10.40s/it]
# Generating samples:  21%|██        | 42/200 [07:17<27:17, 10.37s/it]
# Generating samples:  22%|██▏       | 43/200 [07:28<27:26, 10.49s/it]
# Generating samples:  22%|██▏       | 44/200 [07:38<27:16, 10.49s/it]
# Generating samples:  82%|████████▏ | 163/200 [28:21<06:20, 10.28s/it]
# Generating samples:  82%|████████▏ | 164/200 [28:32<06:16, 10.44s/it]
# Generating samples:  82%|████████▎ | 165/200 [28:42<06:03, 10.37s/it]
# Generating samples:  83%|████████▎ | 166/200 [28:53<05:52, 10.37s/it]
# Generating samples:  84%|████████▎ | 167/200 [29:03<05:43, 10.41s/it]
# Generating samples:  84%|████████▍ | 168/200 [29:14<05:33, 10.41s/it]
# Generating samples:  84%|████████▍ | 169/200 [29:24<05:22, 10.41s/it]
# Generating samples:  85%|████████▌ | 170/200 [29:35<05:15, 10.50s/it]
# Generating samples:  86%|████████▌ | 171/200 [29:46<05:09, 10.67s/it]
# Generating samples:  86%|████████▌ | 172/200 [29:56<04:56, 10.58s/it]
# Generating samples:  86%|████████▋ | 173/200 [30:07<04:44, 10.53s/it]
# Generating samples:  87%|████████▋ | 174/200 [30:17<04:32, 10.48s/it]
# Generating samples:  88%|████████▊ | 175/200 [30:27<04:20, 10.40s/it]
# Generating samples:  88%|████████▊ | 176/200 [30:38<04:10, 10.42s/it]
# Generating samples:  88%|████████▊ | 177/200 [30:48<04:00, 10.47s/it]
# Generating samples:  89%|████████▉ | 178/200 [30:58<03:48, 10.40s/it]
# Generating samples:  90%|████████▉ | 179/200 [31:09<03:39, 10.46s/it]
# Generating samples:  90%|█████████ | 180/200 [31:20<03:29, 10.46s/it]
# Generating samples:  90%|█████████ | 181/200 [31:30<03:17, 10.42s/it]
# Generating samples:  91%|█████████ | 182/200 [31:41<03:11, 10.63s/it]
# Generating samples:  92%|█████████▏| 183/200 [31:51<02:58, 10.51s/it]
# Generating samples:  92%|█████████▏| 184/200 [32:02<02:47, 10.49s/it]
# Generating samples:  92%|█████████▎| 185/200 [32:12<02:37, 10.50s/it]
# Generating samples:  93%|█████████▎| 186/200 [32:22<02:25, 10.39s/it]
# Generating samples:  94%|█████████▎| 187/200 [32:33<02:15, 10.43s/it]
# Generating samples:  94%|█████████▍| 188/200 [32:44<02:07, 10.66s/it]
# Generating samples:  94%|█████████▍| 189/200 [32:54<01:56, 10.60s/it]
# Generating samples:  95%|█████████▌| 190/200 [33:05<01:45, 10.51s/it]
# Generating samples:  96%|█████████▌| 191/200 [33:15<01:34, 10.46s/it]
# Generating samples:  96%|█████████▌| 192/200 [33:26<01:23, 10.44s/it]
# Generating samples:  96%|█████████▋| 193/200 [33:36<01:13, 10.50s/it]
# Generating samples:  97%|█████████▋| 194/200 [33:47<01:03, 10.53s/it]
# Generating samples:  98%|█████████▊| 195/200 [33:57<00:52, 10.47s/it]
# Generating samples:  98%|█████████▊| 196/200 [34:08<00:41, 10.47s/it]
# Generating samples:  98%|█████████▊| 197/200 [34:18<00:31, 10.40s/it]
# Generating samples:  99%|█████████▉| 198/200 [34:28<00:20, 10.35s/it]
# Generating samples: 100%|█████████▉| 199/200 [34:39<00:10, 10.48s/it]
# Generating samples: 100%|██████████| 200/200 [34:49<00:00, 10.45s/it]
# Running 1 MCMC chains in 1 batches.: 100%|██████████| 1/1 [48:14<00:00, 2894.96s/it]
# ------------------------------------------------------------
# --- sampling took: 2895.17916059494 seconds ---

# %%
posterior_samples.shape, params_true.shape
# Out:
# ((200, 85), (85,))

# %%
np.save(os.path.join(cwd+'/'+str(Res_dir), 'BVEP_ode_sbi_sourcelevel_obs2_patient1_posteriorsamples.npy') , posterior_samples)

# %%
eta_posterior=posterior_samples[:,:-1]
K_posterior=posterior_samples[:,-1]

# %%
K_posterior.mean(), K_posterior.std()
# Out:
# (1.2987998, 0.41863587)

# %%
eta_c=-1.95
delta_eta=1.0

# %%
plt.figure(figsize=(15,4))
SEM_violinplot(nn, eta_true, ez_idx, pz_idx, eta_posterior, eta_c, delta_eta )
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_InferredExcitability_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_InferredExcitability_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
plt.figure(figsize=(4,4))
parts= plt.violinplot(K_posterior, widths=0.7, showmeans=True, showextrema=True);
plt.plot(1,params_true[-1] ,'o', color='k', alpha=0.9, markersize=8)
plt.ylabel(' Posterior ' +r'${(K)}$', fontsize=24);  
plt.xlabel(r'${K}$', fontsize=24); 
plt.yticks(fontsize=16)
plt.xticks([])
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_InferredCoupling_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_InferredCoupling_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
estimated_posterior=np.percentile(posterior_samples, [50], axis=0).reshape(-1)

# %%
y_fit_source =VEP2Dmodel(estimated_posterior, constants, init_conditions, dt, ts, SC)

yfit_source=y_fit_source.reshape(nn, int(y_fit_source.shape[0]/nn))

# %%
y_fit=yfit_source
y_fit.shape
# Out:
# (84, 141)

# %%
np.save(os.path.join(cwd+'/'+str(Res_dir), 'BVEP_ode_sbi_sourcelevel_obs2_patient1_y_obs.npy') , y_obs)
np.save(os.path.join(cwd+'/'+str(Res_dir), 'BVEP_ode_sbi_sourcelevel_obs2_patient1_y_fit.npy') , y_fit)

# %%
Rois=np.array([1, 5, 6, 11, 27, 34, 50])

plt.figure(figsize=(10,4))
for roi in Rois:
    plt.plot(y_obs.T[:,roi], '.')
    plt.plot(y_fit.T[:,roi] )
plt.title("Observation vs prediction",fontsize=15)
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source signals', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.show()

# %%
plt.figure(figsize=(12,4))

plt.subplot(121);
plt.plot(y_obs.T)
plt.title("Simulated Source data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)

plt.subplot(122)
plt.plot(y_fit.T)
plt.title(" Predicted Source data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_FittedBVEP_ode_obs2_observation_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_FittedBVEP_ode_obs2_observation_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
plt.figure(figsize=(14, 4))
plt.subplot(121);
plt.imshow(y_obs, aspect='auto', interpolation='bilinear',  origin='lower', cmap='Reds')
plt.title("Simulated Source data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.colorbar();

plt.subplot(122)
plt.imshow(y_fit, aspect='auto', interpolation='bilinear',  origin='lower', cmap='Reds')
plt.title(" Predicted Source data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0) 
plt.colorbar();

plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_ImshowFittedBVEP_ode_obs2_observation_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_ImshowFittedBVEP_ode_obs2_observation_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
eta_true.shape, eta_posterior.shape
# Out:
# ((84,), (200, 84))

# %%
true_labels_nodes,est_labels_nodes =SME_labels(eta_true, eta_posterior.transpose(), eta_c, delta_eta)

# %%
Confusion_matrix_values= confusion_matrix(true_labels_nodes, est_labels_nodes, labels=["EZ", "PZ", "HZ"])
print('Confusion_matrix_values= \n', Confusion_matrix_values)
# Out:
# Confusion_matrix_values=
#  [[ 2  0  0]
#  [ 0  4  0]
#  [ 0  0 78]]

# %%
plt.figure(figsize=(8, 6))
plot_confusion_matrix(Confusion_matrix_values, ["EZ", "PZ", "HZ"])
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_ConfusionMatrix_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_ConfusionMatrix_K_"+str(K_true)+".svg"), dpi=800)
plt.tight_layout()
plt.show()

# %%
np.sum(np.std(eta_posterior, axis=0))
# Out:
# 6.001936

# %%
from report_metrics import LSE, Err, RMSE, LSE_obs, z_score, shrinkage

# %%
eta_est_mu=np.mean(eta_posterior, axis=0)
eta_est_std=np.std(eta_posterior, axis=0)

# %%
b=-7
a=-1
prior_std =np.sqrt((1/12)*(b-a)**2)

# %%
def plot_zscore_shrinkage(nodes, eta_true, eta_est_mu, eta_est_std, prior_std):
    z_score_eta=z_score(eta_true, eta_est_mu, eta_est_std)
    colors= np.random.rand(z_score_eta.shape[0])
    plt.scatter(shrinkage([prior_std]*nodes.shape[0], eta_est_std), z_score_eta ,s=120, c='blue')
    plt.xlabel("Posterior shrinkages", fontsize=24)
    plt.ylabel("Posterior z-scores", fontsize=24)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
plot_zscore_shrinkage(nodes, eta_true, eta_est_mu, eta_est_std, prior_std)
plt.axis((-.1,1.1,-2,20))
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_zscore_shrinkage_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs2_zscore_shrinkage_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
Err(eta_true, eta_est_mu), RMSE(eta_true, eta_est_mu)
# Out:
# (3.7512557744979844, 0.05928005628801921)

# %%
Err(y_obs, y_fit), RMSE(y_obs, y_fit)
# Out:
# (147.86122073123795, 0.018723946183744712)

# %%
shrinkage([prior_std]*nodes.shape[0], eta_est_std).shape
# Out:
# (84,)

# %%
from sklearn import metrics
from itertools import cycle
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize

# %%
n_classes=3
node_classes=['HZ', 'PZ', 'EZ']

# %%
true_nodes=true_node_binary(true_labels_nodes)
estimated_nodes=estimated_node_binary(est_labels_nodes)

# %%
y_true=label_binarize(true_nodes, classes=[0, 1, 2])
y_pred=label_binarize(estimated_nodes, classes=[0, 1, 2])

# %%
y_true.shape, y_pred.shape
# Out:
# ((84, 3), (84, 3))

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()


for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])
    
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = metrics.roc_curve(y_true.ravel(), y_pred.ravel())
roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])    


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = metrics.auc(fpr["macro"], tpr["macro"])

# %%
# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class '+ str(node_classes[i])+' (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-.01, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=22)
plt.ylabel('True Positive Rate', fontsize=22)
plt.title('ROC for amortized inference of SEEG', fontsize=18)
plt.legend(loc="lower right")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"ROC_obs2_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"ROC_obs2_K_"+str(K_true)+".png"), dpi=800)
plt.show()

# %%
fpr
# Out:
# {0: array([0., 0., 1.]),
#  1: array([0., 0., 1.]),
#  2: array([0., 0., 1.]),
#  'micro': array([0., 0., 1.]),
#  'macro': array([0., 1.])}

# %%
tpr
# Out:
# {0: array([0., 1., 1.]),
#  1: array([0., 1., 1.]),
#  2: array([0., 1., 1.]),
#  'micro': array([0., 1., 1.]),
#  'macro': array([1., 1.])}

# %%
roc_auc["micro"], roc_auc["macro"]
# Out:
# (1.0, 1.0)

# %% [markdown]
# ### Another Data set

# %%
hz_val=-3.65
pz_val=-2.4
ez_val=-1.6

ez_idx = np.array([6, 34, 18, 45, 67, 81],  dtype=np.int32)
pz_wplng_idx = np.array([5,11], dtype=np.int32)
pz_kplng_idx = np.array([27], dtype=np.int32)
pz_idx = np.append(pz_kplng_idx, pz_wplng_idx)

# %%
eta_true = np.ones(nn)*hz_val
eta_true[ez_idx] = ez_val
eta_true[pz_idx] = pz_val

# %%
K_true=1.

# %%
x_init=-2.5
z_init=3.5
init_conditions = np.array([x_init, z_init])

# %%
params_true = np.append(eta_true, K_true)
params_true.shape
# Out:
# (85,)

# %%
obs_source =VEP2Dmodel(params_true, constants, init_conditions, dt, ts, SC)
obs_source=obs_source.reshape(nn, int(obs_source.shape[0]/nn))

# %%
plt.figure(figsize=(10,16))
for i in range(0, nn):
    if i in ez_idx:
          plt.plot(obs_source[i,:]+i, 'r', lw=3)
    elif i in pz_idx:
          plt.plot(obs_source[i,:]+i, 'y', lw=3)
    else:  
          plt.plot(obs_source[i,:]+i, 'g')
plt.yticks(np.r_[0:nn]-2, np.r_[0:nn],fontsize=10)
plt.xticks(fontsize=16)
plt.title("Source brain activity",fontsize=18)
plt.xlabel('Time',fontsize=22)
plt.ylabel('Brain Regions#',fontsize=22)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_source_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_source_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
obs_summary_statistics=calculate_summary_statistics_features(obs_source.reshape(-1),  nn, nt, dt, ts, features=['seizures_onset'])

# %%
obs_source.shape, obs_summary_statistics.shape
# Out:
# ((84, 141), (588,))

# %%
y_obs=obs_source
y_obs.shape
# Out:
# (84, 141)

# %%
plt.figure(figsize=(10,6))
plt.plot(obs_source.T)
plt.title("Source activity signals",fontsize=15)
plt.xlabel('Time',fontsize=12)
plt.ylabel('Regions#',fontsize=12)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_seeg_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_seeg_K_"+str(K_true)+".svg"), dpi=800)

# %% [markdown]
# ### Posterior

# %%
nodes=np.r_[0:nn]

# %%
num_samples=200

# %%
start_time = time.time()

posterior_samples = posterior.sample((num_samples,), obs_summary_statistics).numpy()

print ("-"*60)
print("--- sampling took: %s seconds ---" % (time.time() - start_time))
# Out:
# Running 1 MCMC chains in 1 batches.:   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#
# Tuning bracket width...:  76%|███████▌  | 38/50 [10:05<00:13,  1.09s/it]
# Tuning bracket width...:  78%|███████▊  | 39/50 [10:06<00:12,  1.12s/it]
# Tuning bracket width...:  80%|████████  | 40/50 [10:08<00:11,  1.17s/it]
# Tuning bracket width...:  82%|████████▏ | 41/50 [10:09<00:10,  1.14s/it]
# Tuning bracket width...:  84%|████████▍ | 42/50 [10:10<00:08,  1.11s/it]
# Tuning bracket width...:  86%|████████▌ | 43/50 [10:11<00:07,  1.09s/it]
# Tuning bracket width...:  88%|████████▊ | 44/50 [10:12<00:06,  1.09s/it]
# Tuning bracket width...:  90%|█████████ | 45/50 [10:13<00:05,  1.08s/it]
# Tuning bracket width...:  92%|█████████▏| 46/50 [10:14<00:04,  1.08s/it]
# Tuning bracket width...:  94%|█████████▍| 47/50 [10:15<00:03,  1.06s/it]
# Tuning bracket width...:  96%|█████████▌| 48/50 [10:16<00:02,  1.05s/it]
# Tuning bracket width...:  98%|█████████▊| 49/50 [10:17<00:01,  1.06s/it]
# Tuning bracket width...: 100%|██████████| 50/50 [10:18<00:00, 12.38s/it]
#
#   0%|          | 0/10 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/10 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/10 [00:11<?, ?it/s]
# Generating samples:  20%|██        | 2/10 [00:21<01:27, 10.93s/it]
# Generating samples:  30%|███       | 3/10 [00:32<01:15, 10.77s/it]
# Generating samples:  40%|████      | 4/10 [00:43<01:04, 10.80s/it]
# Generating samples:  50%|█████     | 5/10 [00:54<00:54, 10.92s/it]
# Generating samples:  60%|██████    | 6/10 [01:05<00:43, 10.88s/it]
# Generating samples:  70%|███████   | 7/10 [01:15<00:32, 10.79s/it]
# Generating samples:  80%|████████  | 8/10 [01:26<00:21, 10.70s/it]
# Generating samples:  90%|█████████ | 9/10 [01:36<00:10, 10.68s/it]
# Generating samples: 100%|██████████| 10/10 [01:47<00:00, 10.78s/it]
#
#   0%|          | 0/200 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/200 [00:00<?, ?it/s]
# Generating samples:   0%|          | 0/200 [00:10<?, ?it/s]
# Generating samples:   0%|          | 1/200 [00:11<36:34, 11.03s/it]
# Generating samples:   1%|          | 2/200 [00:21<35:22, 10.72s/it]
# Generating samples:   2%|▏         | 3/200 [00:31<34:47, 10.60s/it]
# Generating samples:   2%|▏         | 4/200 [00:42<35:05, 10.74s/it]
# Generating samples:   2%|▎         | 5/200 [00:54<35:18, 10.87s/it]
# Generating samples:   3%|▎         | 6/200 [01:04<34:55, 10.80s/it]
# Generating samples:   4%|▎         | 7/200 [01:15<35:05, 10.91s/it]
# Generating samples:   4%|▍         | 8/200 [01:26<34:45, 10.86s/it]
# Generating samples:   4%|▍         | 9/200 [01:37<34:09, 10.73s/it]
# Generating samples:   5%|▌         | 10/200 [01:47<33:57, 10.72s/it]
# Generating samples:   6%|▌         | 11/200 [01:58<33:43, 10.71s/it]
# Generating samples:   6%|▌         | 12/200 [02:09<33:26, 10.67s/it]
# Generating samples:   6%|▋         | 13/200 [02:19<33:01, 10.59s/it]
# Generating samples:  86%|████████▋ | 173/200 [30:50<04:51, 10.80s/it]
# Generating samples:  87%|████████▋ | 174/200 [31:00<04:40, 10.77s/it]
# Generating samples:  88%|████████▊ | 175/200 [31:11<04:28, 10.74s/it]
# Generating samples:  88%|████████▊ | 176/200 [31:22<04:18, 10.78s/it]
# Generating samples:  88%|████████▊ | 177/200 [31:33<04:06, 10.70s/it]
# Generating samples:  89%|████████▉ | 178/200 [31:43<03:56, 10.76s/it]
# Generating samples:  90%|████████▉ | 179/200 [31:54<03:45, 10.73s/it]
# Generating samples:  90%|█████████ | 180/200 [32:05<03:33, 10.69s/it]
# Generating samples:  90%|█████████ | 181/200 [32:15<03:22, 10.65s/it]
# Generating samples:  91%|█████████ | 182/200 [32:26<03:12, 10.72s/it]
# Generating samples:  92%|█████████▏| 183/200 [32:37<03:01, 10.69s/it]
# Generating samples:  92%|█████████▏| 184/200 [32:47<02:50, 10.66s/it]
# Generating samples:  92%|█████████▎| 185/200 [32:58<02:40, 10.67s/it]
# Generating samples:  93%|█████████▎| 186/200 [33:09<02:29, 10.66s/it]
# Generating samples:  94%|█████████▎| 187/200 [33:19<02:18, 10.66s/it]
# Generating samples:  94%|█████████▍| 188/200 [33:30<02:07, 10.64s/it]
# Generating samples:  94%|█████████▍| 189/200 [33:41<01:57, 10.71s/it]
# Generating samples:  95%|█████████▌| 190/200 [33:52<01:47, 10.72s/it]
# Generating samples:  96%|█████████▌| 191/200 [34:02<01:36, 10.71s/it]
# Generating samples:  96%|█████████▌| 192/200 [34:13<01:25, 10.70s/it]
# Generating samples:  96%|█████████▋| 193/200 [34:24<01:15, 10.78s/it]
# Generating samples:  97%|█████████▋| 194/200 [34:34<01:04, 10.72s/it]
# Generating samples:  98%|█████████▊| 195/200 [34:45<00:53, 10.69s/it]
# Generating samples:  98%|█████████▊| 196/200 [34:56<00:42, 10.66s/it]
# Generating samples:  98%|█████████▊| 197/200 [35:06<00:32, 10.71s/it]
# Generating samples:  99%|█████████▉| 198/200 [35:17<00:21, 10.78s/it]
# Generating samples: 100%|█████████▉| 199/200 [35:28<00:10, 10.76s/it]
# Generating samples: 100%|██████████| 200/200 [35:39<00:00, 10.70s/it]
# Running 1 MCMC chains in 1 batches.: 100%|██████████| 1/1 [47:45<00:00, 2865.72s/it]
# ------------------------------------------------------------
# --- sampling took: 2865.9429433345795 seconds ---

# %%
posterior_samples.shape, params_true.shape
# Out:
# ((200, 85), (85,))

# %%
np.save(os.path.join(cwd+'/'+str(Res_dir), 'BVEP_ode_sbi_sourcelevel_obs3_patient1_posteriorsamples.npy') , posterior_samples)

# %%
eta_posterior=posterior_samples[:,:-1]
K_posterior=posterior_samples[:,-1]

# %%
K_posterior.mean(), K_posterior.std()
# Out:
# (1.3034787, 0.3635054)

# %%
eta_c=-1.95
delta_eta=1.0

# %%
plt.figure(figsize=(15,4))
SEM_violinplot(nn, eta_true, ez_idx, pz_idx, eta_posterior, eta_c, delta_eta )
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_InferredExcitability_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_InferredExcitability_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
plt.figure(figsize=(4,4))
parts= plt.violinplot(K_posterior, widths=0.7, showmeans=True, showextrema=True);
plt.plot(1,params_true[-1] ,'o', color='k', alpha=0.9, markersize=8)
plt.ylabel(' Posterior ' +r'${(K)}$', fontsize=24);  
plt.xlabel(r'${K}$', fontsize=24); 
plt.yticks(fontsize=16)
plt.xticks([])
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_InferredCoupling_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_InferredCoupling_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
estimated_posterior=np.percentile(posterior_samples, [50], axis=0).reshape(-1)

# %%
y_fit_source =VEP2Dmodel(estimated_posterior, constants, init_conditions, dt, ts, SC)

yfit_source=y_fit_source.reshape(nn, int(y_fit_source.shape[0]/nn))

# %%
y_fit=yfit_source
y_fit.shape
# Out:
# (84, 141)

# %%
np.save(os.path.join(cwd+'/'+str(Res_dir), 'BVEP_ode_sbi_sourcelevel_obs3_patient1_y_obs.npy') , y_obs)
np.save(os.path.join(cwd+'/'+str(Res_dir), 'BVEP_ode_sbi_sourcelevel_obs3_patient1_y_obs.npy') , y_fit)

# %%
Rois=np.array([1, 5, 6, 11,18,  27, 34, 45, 50, 67, 81])

plt.figure(figsize=(10,4))
for roi in Rois:
    plt.plot(y_obs.T[:,roi], '.')
    plt.plot(y_fit.T[:,roi] )
plt.title("Observation vs prediction",fontsize=15)
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source signals', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.show()

# %%
plt.figure(figsize=(12,4))

plt.subplot(121);
plt.plot(y_obs.T)
plt.title("Simulated Source data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)

plt.subplot(122)
plt.plot(y_fit.T)
plt.title(" Predicted Source data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_FittedBVEP_ode_obs3_observation_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_FittedBVEP_ode_obs3_observation_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
plt.figure(figsize=(14, 4))
plt.subplot(121);
plt.imshow(y_obs, aspect='auto', interpolation='bilinear',  origin='lower', cmap='Reds')
plt.title("Simulated Source data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0)
plt.colorbar();

plt.subplot(122)
plt.imshow(y_fit, aspect='auto', interpolation='bilinear',  origin='lower', cmap='Reds')
plt.title(" Predicted Source data", fontsize=22) 
plt.xlabel('Time', fontsize=22)
plt.ylabel('Source activity', fontsize=22)
plt.yticks(fontsize=18, rotation=0)
plt.xticks(fontsize=18, rotation=0) 
plt.colorbar();

plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_ImshowFittedBVEP_ode_obs3_observation_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_ImshowFittedBVEP_ode_obs3_observation_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
eta_true.shape, eta_posterior.shape
# Out:
# ((84,), (200, 84))

# %%
true_labels_nodes,est_labels_nodes =SME_labels(eta_true, eta_posterior.transpose(), eta_c, delta_eta)

# %%
Confusion_matrix_values= confusion_matrix(true_labels_nodes, est_labels_nodes, labels=["EZ", "PZ", "HZ"])
print('Confusion_matrix_values= \n', Confusion_matrix_values)
# Out:
# Confusion_matrix_values=
#  [[ 6  0  0]
#  [ 0  3  0]
#  [ 0  0 75]]

# %%
plt.figure(figsize=(8, 6))
plot_confusion_matrix(Confusion_matrix_values, ["EZ", "PZ", "HZ"])
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_ConfusionMatrix_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_ConfusionMatrix_K_"+str(K_true)+".svg"), dpi=800)
plt.tight_layout()
plt.show()

# %%
np.sum(np.std(eta_posterior, axis=0))
# Out:
# 5.9103208

# %%
from report_metrics import LSE, Err, RMSE, LSE_obs, z_score, shrinkage

# %%
eta_est_mu=np.mean(eta_posterior, axis=0)
eta_est_std=np.std(eta_posterior, axis=0)

# %%
b=-7
a=-1
prior_std =np.sqrt((1/12)*(b-a)**2)

# %%
def plot_zscore_shrinkage(nodes, eta_true, eta_est_mu, eta_est_std, prior_std):
    z_score_eta=z_score(eta_true, eta_est_mu, eta_est_std)
    colors= np.random.rand(z_score_eta.shape[0])
    plt.scatter(shrinkage([prior_std]*nodes.shape[0], eta_est_std), z_score_eta ,s=120, c='blue')
    plt.xlabel("Posterior shrinkages", fontsize=24)
    plt.ylabel("Posterior z-scores", fontsize=24)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
plot_zscore_shrinkage(nodes, eta_true, eta_est_mu, eta_est_std, prior_std)
plt.axis((-.1,1.1,-2,20))
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_zscore_shrinkage_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"SBI_BVEP_ode_obs3_zscore_shrinkage_K_"+str(K_true)+".svg"), dpi=800)
plt.show()

# %%
Err(eta_true, eta_est_mu), RMSE(eta_true, eta_est_mu)
# Out:
# (3.526425838470459, 0.05755294416792744)

# %%
Err(y_obs, y_fit), RMSE(y_obs, y_fit)
# Out:
# (227.60943474172694, 0.06409099099473947)

# %%
shrinkage([prior_std]*nodes.shape[0], eta_est_std).shape
# Out:
# (84,)

# %%
n_classes=3
node_classes=['HZ', 'PZ', 'EZ']

# %%
from sklearn import metrics
from itertools import cycle
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize

# %%
true_nodes=true_node_binary(true_labels_nodes)
estimated_nodes=estimated_node_binary(est_labels_nodes)

# %%
y_true=label_binarize(true_nodes, classes=[0, 1, 2])
y_pred=label_binarize(estimated_nodes, classes=[0, 1, 2])

# %%
y_true.shape, y_pred.shape
# Out:
# ((84, 3), (84, 3))

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()


for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(y_true[:, i], y_pred[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])
    
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = metrics.roc_curve(y_true.ravel(), y_pred.ravel())
roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])    


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = metrics.auc(fpr["macro"], tpr["macro"])

# %%
# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class '+ str(node_classes[i])+' (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-.01, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=22)
plt.ylabel('True Positive Rate', fontsize=22)
plt.title('ROC for amortized inference of SEEG', fontsize=18)
plt.legend(loc="lower right")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.tight_layout()
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"ROC_obs3_K_"+str(K_true)+".png"), dpi=800)
plt.savefig(os.path.join(cwd+'/'+str(Res_dir),"ROC_obs3_K_"+str(K_true)+".png"), dpi=800)
plt.show()

# %%
fpr
# Out:
# {0: array([0., 0., 1.]),
#  1: array([0., 0., 1.]),
#  2: array([0., 0., 1.]),
#  'micro': array([0., 0., 1.]),
#  'macro': array([0., 1.])}

# %%
tpr
# Out:
# {0: array([0., 1., 1.]),
#  1: array([0., 1., 1.]),
#  2: array([0., 1., 1.]),
#  'micro': array([0., 1., 1.]),
#  'macro': array([1., 1.])}

# %%
roc_auc["micro"], roc_auc["macro"]
# Out:
# (1.0, 1.0)
